# %% [markdown]
# <a href="https://colab.research.google.com/github/Pengu007/Translational_Model/blob/main/Translation_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing the Dataset (Multi-30K)**

# %%
! git clone --recursive https://github.com/multi30k/dataset.git multi30k-dataset
# Out:
# Cloning into 'multi30k-dataset'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 313 (delta 17), reused 21 (delta 16), pack-reused 281
# Receiving objects: 100% (313/313), 18.21 MiB | 26.82 MiB/s, done.
# Resolving deltas: 100% (69/69), done.
# Submodule 'scripts/subword-nmt' (https://github.com/rsennrich/subword-nmt.git) registered for path 'scripts/subword-nmt'
# Cloning into '/content/multi30k-dataset/scripts/subword-nmt'...
# remote: Enumerating objects: 597, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 597 (delta 8), reused 12 (delta 4), pack-reused 576
# Receiving objects: 100% (597/597), 252.23 KiB | 10.51 MiB/s, done.
# Resolving deltas: 100% (357/357), done.
# Submodule path 'scripts/subword-nmt': checked out '80b7c1449e2e26673fb0b5cae993fe2d0dc23846'

# %% [markdown]
# **Installing Required Python Modules**

# %%
# %%capture
# W and B -- For Logging
! pip install wandb

# Sacremoses -- For Tokenizing
! pip install sacremoses

# fairseq -- For training and evaluation of the model
! git clone https://github.com/pytorch/fairseq
# %cd fairseq
! pip install --editable ./
# %cd ..

# %% [markdown]
# **To use W and B, Creating and Logging in Account**

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: mail2anandved (alone_y1). Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# **Pre-process and Binarize to build Vocabularies**

# %%
! fairseq-preprocess --source-lang de --target-lang en \
  --trainpref multi30k-dataset/data/task1/tok/train.lc.norm.tok \
  --validpref multi30k-dataset/data/task1/tok/val.lc.norm.tok \
  --testpref  multi30k-dataset/data/task1/tok/test_2018_flickr.lc.norm.tok \
  --destdir data-bin/multi30k.tokenized.de-en \
  --thresholdsrc 2 \
  --thresholdtgt 2
# Out:
# 2023-11-24 12:22:27.511524: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 12:22:27.511606: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 12:22:27.511665: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-24 12:22:27.527110: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 12:22:29.920131: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:fairseq.tasks.text_to_speech:Please install tensorboardX: pip install tensorboardX
# INFO:fairseq_cli.preprocess:Namespace(no_progress_bar=False, log_interval=100, log_format=None, log_file=None, aim_repo=None, aim_run_hash=None, tensorboard_logdir=None, wandb_project=None, azureml_logging=False, seed=1, cpu=False, tpu=False, bf16=False, memory_efficient_bf16=False, fp16=False, memory_efficient_fp16=False, fp16_no_flatten_grads=False, fp16_init_scale=128, fp16_scale_window=None, fp16_scale_tolerance=0.0, on_cpu_convert_precision=False, min_loss_scale=0.0001, threshold_loss_scale=None, amp=False, amp_batch_retries=2, amp_init_scale=128, amp_scale_window=None, user_dir=None, empty_cache_freq=0, all_gather_list_size=16384, model_parallel_size=1, quantization_config_path=None, profile=False, reset_logging=False, suppress_crashes=False, use_plasma_view=False, plasma_path='/tmp/plasma', criterion='cross_entropy', tokenizer=None, bpe=None, optimizer=None, lr_scheduler='fixed', scoring='bleu', task='translation', source_lang='de', target_lang='en', trainpref='multi30k-dataset/data/task1/tok/train.lc.norm.tok', validpref='multi30k-dataset/data/task1/tok/val.lc.norm.tok', testpref='multi30k-dataset/data/task1/tok/test_2018_flickr.lc.norm.tok', align_suffix=None, destdir='data-bin/multi30k.tokenized.de-en', thresholdtgt=2, thresholdsrc=2, tgtdict=None, srcdict=None, nwordstgt=-1, nwordssrc=-1, alignfile=None, dataset_impl='mmap', joined_dictionary=False, only_source=False, padding_factor=8, workers=1, dict_only=False)
# INFO:fairseq_cli.preprocess:[de] Dictionary: 7864 types
# INFO:fairseq_cli.preprocess:[de] multi30k-dataset/data/task1/tok/train.lc.norm.tok.de: 29000 sents, 389706 tokens, 2.79% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:[de] Dictionary: 7864 types
# INFO:fairseq_cli.preprocess:[de] multi30k-dataset/data/task1/tok/val.lc.norm.tok.de: 1014 sents, 13842 tokens, 4.11% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:[de] Dictionary: 7864 types
# INFO:fairseq_cli.preprocess:[de] multi30k-dataset/data/task1/tok/test_2018_flickr.lc.norm.tok.de: 1071 sents, 14778 tokens, 5.5% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:[en] Dictionary: 5928 types
# INFO:fairseq_cli.preprocess:[en] multi30k-dataset/data/task1/tok/train.lc.norm.tok.en: 29000 sents, 406534 tokens, 1.06% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:[en] Dictionary: 5928 types
# INFO:fairseq_cli.preprocess:[en] multi30k-dataset/data/task1/tok/val.lc.norm.tok.en: 1014 sents, 14322 tokens, 1.91% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:[en] Dictionary: 5928 types
# INFO:fairseq_cli.preprocess:[en] multi30k-dataset/data/task1/tok/test_2018_flickr.lc.norm.tok.en: 1071 sents, 15768 tokens, 2.05% replaced (by <unk>)
# INFO:fairseq_cli.preprocess:Wrote preprocessed data to data-bin/multi30k.tokenized.de-en

# %% [markdown]
# # Training the model

# %%
! fairseq-train data-bin/multi30k.tokenized.de-en \
  --arch transformer \
  --dropout 0.1 \
  --attention-dropout 0.1 \
  --activation-dropout 0.1 \
  --encoder-embed-dim 256 \
  --encoder-ffn-embed-dim 512 \
  --encoder-layers 3 \
  --encoder-attention-heads 8 \
  --encoder-learned-pos \
  --decoder-embed-dim 256 \
  --decoder-ffn-embed-dim 512 \
  --decoder-layers 3 \
  --decoder-attention-heads 8 \
  --decoder-learned-pos \
  --max-epoch 10 \
  --optimizer adam \
  --lr 5e-4 \
  --batch-size 128 \
  --seed 1 \
  --wandb-project "Multi 30K En to De Translation"
# Out:
# 2023-11-24 12:27:28.769362: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 12:27:28.769453: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 12:27:28.769498: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-24 12:27:28.780899: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 12:27:30.165197: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-11-24 12:27:31 | INFO | numexpr.utils | NumExpr defaulting to 2 threads.
# 2023-11-24 12:27:34 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2023-11-24 12:27:38 | INFO | fairseq_cli.train | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': 'Multi 30K En to De Translation', 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': False, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': None, 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': False, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': None, 'batch_size': 128, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': None, 'batch_size_valid': 128, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 10, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.0005], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False, 'debug_param_names': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_ch ...
# 2023-11-24 12:27:38 | INFO | fairseq.tasks.translation | [de] dictionary: 7864 types
# 2023-11-24 12:27:38 | INFO | fairseq.tasks.translation | [en] dictionary: 5928 types
# 2023-11-24 12:27:39 | INFO | fairseq_cli.train | TransformerModel(
#   (encoder): TransformerEncoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(7864, 256, padding_idx=1)
#     (embed_positions): LearnedPositionalEmbedding(1026, 256, padding_idx=1)
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayerBase(
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (dropout_module): FairseqDropout()
#         (activation_dropout_module): FairseqDropout()
#         (fc1): Linear(in_features=256, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (decoder): TransformerDecoderBase(
#     (dropout_module): FairseqDropout()
#     (embed_tokens): Embedding(5928, 256, padding_idx=1)
#     (embed_positions): LearnedPositionalEmbedding(1026, 256, padding_idx=1)
#     (layers): ModuleList(
#       (0-2): 3 x TransformerDecoderLayerBase(
#         (dropout_module): FairseqDropout()
#         (self_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (activation_dropout_module): FairseqDropout()
#         (self_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (encoder_attn): MultiheadAttention(
#           (dropout_module): FairseqDropout()
#           (k_proj): Linear(in_features=256, out_features=256, bias=True)
#           (v_proj): Linear(in_features=256, out_features=256, bias=True)
#           (q_proj): Linear(in_features=256, out_features=256, bias=True)
#           (out_proj): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (encoder_attn_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (fc1): Linear(in_features=256, out_features=512, bias=True)
#         (fc2): Linear(in_features=512, out_features=256, bias=True)
#         (final_layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_projection): Linear(in_features=256, out_features=5928, bias=False)
#   )
# )
# 2023-11-24 12:27:39 | INFO | fairseq_cli.train | task: TranslationTask
# 2023-11-24 12:27:39 | INFO | fairseq_cli.train | model: TransformerModel
# 2023-11-24 12:27:39 | INFO | fairseq_cli.train | criterion: CrossEntropyCriterion
# 2023-11-24 12:27:39 | INFO | fairseq_cli.train | num. shared model params: 9,527,296 (num. trained: 9,527,296)
# 2023-11-24 12:27:39 | INFO | fairseq_cli.train | num. expert model params: 0 (num. trained: 0)
# 2023-11-24 12:27:39 | INFO | fairseq.data.data_utils | loaded 1,014 examples from: data-bin/multi30k.tokenized.de-en/valid.de-en.de
# 2023-11-24 12:27:39 | INFO | fairseq.data.data_utils | loaded 1,014 examples from: data-bin/multi30k.tokenized.de-en/valid.de-en.en
# 2023-11-24 12:27:39 | INFO | fairseq.tasks.translation | data-bin/multi30k.tokenized.de-en valid de-en 1014 examples
# 2023-11-24 12:27:39 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2023-11-24 12:27:39 | INFO | fairseq_cli.train | max tokens per device = None and max sentences per device = 128
# 2023-11-24 12:27:39 | INFO | fairseq.trainer | Preparing to load checkpoint checkpoints/checkpoint_last.pt
# 2023-11-24 12:27:39 | INFO | fairseq.trainer | No existing checkpoint found checkpoints/checkpoint_last.pt
# 2023-11-24 12:27:39 | INFO | fairseq.trainer | loading train data for epoch 1
# 2023-11-24 12:27:39 | INFO | fairseq.data.data_utils | loaded 29,000 examples from: data-bin/multi30k.tokenized.de-en/train.de-en.de
# 2023-11-24 12:27:39 | INFO | fairseq.data.data_utils | loaded 29,000 examples from: data-bin/multi30k.tokenized.de-en/train.de-en.en
# 2023-11-24 12:27:39 | INFO | fairseq.tasks.translation | data-bin/multi30k.tokenized.de-en train de-en 29000 examples
# 2023-11-24 12:27:39 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 12:27:39 | INFO | fairseq.tasks.fairseq_task | reuse_dataloader = True
# 2023-11-24 12:27:39 | INFO | fairseq.tasks.fairseq_task | rebuild_batches = False
# 2023-11-24 12:27:39 | INFO | fairseq.tasks.fairseq_task | creating new batches for epoch 1
# 2023-11-24 12:27:39 | INFO | fairseq_cli.train | begin dry-run validation on "valid" subset
# 2023-11-24 12:27:39 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 12:27:39 | INFO | fairseq.tasks.fairseq_task | reuse_dataloader = True
# 2023-11-24 12:27:39 | INFO | fairseq.tasks.fairseq_task | rebuild_batches = False
# 2023-11-24 12:27:39 | INFO | fairseq.tasks.fairseq_task | creating new batches for epoch 1
# 2023-11-24 12:27:39 | INFO | fairseq.data.iterators | grouped total_num_itrs = 227
# epoch 001:   0% 0/227 [00:00<?, ?it/s]wandb: Currently logged in as: mail2anandved (alone_y1). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /content/wandb/run-20231124_122740-wp8bnwe4
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run checkpoints
# wandb: ⭐️ View project at https://wandb.ai/alone_y1/Multi%2030K%20En%20to%20De%20Translation
# wandb: 🚀 View run at https://wandb.ai/alone_y1/Multi%2030K%20En%20to%20De%20Translation/runs/wp8bnwe4
# 2023-11-24 12:27:40 | INFO | fairseq.trainer | begin training epoch 1
# 2023-11-24 12:27:40 | INFO | fairseq_cli.train | Start iterating over samples
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5076: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# epoch 001: 100% 226/227 [06:05<00:01,  1.21s/it, loss=5.139, ppl=35.23, wps=1109.2, ups=0.61, wpb=1832.8, bsz=127.4, num_updates=200, lr=0.0005, gnorm=1.146, train_wall=164, wall=326]2023-11-24 12:33:46 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-11-24 12:33:46 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
#
# epoch 001 | valid on 'valid' subset:   0% 0/8 [00:00<?, ?it/s]
# epoch 001 | valid on 'valid' subset:  12% 1/8 [00:00<00:02,  2.46it/s]
# epoch 001 | valid on 'valid' subset:  25% 2/8 [00:00<00:02,  2.36it/s]
# epoch 001 | valid on 'valid' subset:  38% 3/8 [00:01<00:02,  2.36it/s]
# epoch 001 | valid on 'valid' subset:  50% 4/8 [00:01<00:01,  2.26it/s]
# epoch 001 | valid on 'valid' subset:  62% 5/8 [00:02<00:01,  2.16it/s]
# epoch 001 | valid on 'valid' subset:  75% 6/8 [00:02<00:01,  1.93it/s]
# epoch 001 | valid on 'valid' subset:  88% 7/8 [00:03<00:00,  1.73it/s]
# epoch 001 | valid on 'valid' subset: 100% 8/8 [00:04<00:00,  1.53it/s]
#                                                                       2023-11-24 12:33:50 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 4.236 | ppl 18.85 | wps 3262.7 | wpb 1768.6 | bsz 126 | num_updates 227
# 2023-11-24 12:33:50 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 1 @ 227 updates
# 2023-11-24 12:33:50 | INFO | fairseq.trainer | Saving checkpoint to /content/checkpoints/checkpoint1.pt
# 2023-11-24 12:33:50 | INFO | fairseq.trainer | Finished saving checkpoint to /content/checkpoints/checkpoint1.pt
# 2023-11-24 12:33:51 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint1.pt (epoch 1 @ 227 updates, score 4.236) (writing took 1.1361446640003123 seconds)
# 2023-11-24 12:33:51 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2023-11-24 12:33:51 | INFO | train | epoch 001 | loss 5.78 | ppl 54.94 | wps 1099.9 | ups 0.62 | wpb 1790.9 | bsz 127.8 | num_updates 227 | lr 0.0005 | gnorm 1.32 | train_wall 363 | wall 373
# 2023-11-24 12:33:51 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 12:33:51 | INFO | fairseq.data.iterators | grouped total_num_itrs = 227
# epoch 002:   0% 0/227 [00:00<?, ?it/s]2023-11-24 12:33:51 | INFO | fairseq.trainer | begin training epoch 2
# 2023-11-24 12:33:51 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 002: 100% 226/227 [06:06<00:01,  1.84s/it, loss=3.96, ppl=15.56, wps=1107.8, ups=0.62, wpb=1798.5, bsz=128, num_updates=400, lr=0.0005, gnorm=1.137, train_wall=161, wall=649]2023-11-24 12:39:59 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-11-24 12:39:59 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
#
# epoch 002 | valid on 'valid' subset:   0% 0/8 [00:00<?, ?it/s]
# epoch 002 | valid on 'valid' subset:  12% 1/8 [00:00<00:02,  2.38it/s]
# epoch 002 | valid on 'valid' subset:  25% 2/8 [00:00<00:02,  2.18it/s]
# epoch 002 | valid on 'valid' subset:  38% 3/8 [00:01<00:02,  2.30it/s]
# epoch 002 | valid on 'valid' subset:  50% 4/8 [00:01<00:01,  2.11it/s]
# epoch 002 | valid on 'valid' subset:  62% 5/8 [00:02<00:01,  2.10it/s]
# epoch 002 | valid on 'valid' subset:  75% 6/8 [00:02<00:01,  1.92it/s]
# epoch 002 | valid on 'valid' subset:  88% 7/8 [00:03<00:00,  1.68it/s]
# epoch 002 | valid on 'valid' subset: 100% 8/8 [00:04<00:00,  1.46it/s]
#                                                                       2023-11-24 12:40:04 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 3.454 | ppl 10.96 | wps 3129.1 | wpb 1768.6 | bsz 126 | num_updates 454 | best_loss 3.454
# 2023-11-24 12:40:04 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 2 @ 454 updates
# 2023-11-24 12:40:04 | INFO | fairseq.trainer | Saving checkpoint to /content/checkpoints/checkpoint2.pt
# 2023-11-24 12:40:04 | INFO | fairseq.trainer | Finished saving checkpoint to /content/checkpoints/checkpoint2.pt
# 2023-11-24 12:40:04 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint2.pt (epoch 2 @ 454 updates, score 3.454) (writing took 0.7809128600001713 seconds)
# 2023-11-24 12:40:04 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2023-11-24 12:40:04 | INFO | train | epoch 002 | loss 4.003 | ppl 16.04 | wps 1089.4 | ups 0.61 | wpb 1790.9 | bsz 127.8 | num_updates 454 | lr 0.0005 | gnorm 1.16 | train_wall 365 | wall 746
# 2023-11-24 12:40:04 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 12:40:04 | INFO | fairseq.data.iterators | grouped total_num_itrs = 227
# epoch 003:   0% 0/227 [00:00<?, ?it/s]2023-11-24 12:40:04 | INFO | fairseq.trainer | begin training epoch 3
# 2023-11-24 12:40:04 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 003: 100% 226/227 [06:06<00:01,  1.77s/it, loss=3.221, ppl=9.32, wps=1097.3, ups=0.64, wpb=1727.2, bsz=128, num_updates=600, lr=0.0005, gnorm=1.135, train_wall=156, wall=981]2023-11-24 12:46:12 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-11-24 12:46:12 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
#
# epoch 003 | valid on 'valid' subset:   0% 0/8 [00:00<?, ?it/s]
# epoch 003 | valid on 'valid' subset:  12% 1/8 [00:00<00:04,  1.52it/s]
# epoch 003 | valid on 'valid' subset:  25% 2/8 [00:01<00:04,  1.49it/s]
# epoch 003 | valid on 'valid' subset:  38% 3/8 [00:01<00:03,  1.55it/s]
# epoch 003 | valid on 'valid' subset:  50% 4/8 [00:02<00:02,  1.50it/s]
# epoch 003 | valid on 'valid' subset:  62% 5/8 [00:03<00:01,  1.62it/s]
# epoch 003 | valid on 'valid' subset:  75% 6/8 [00:03<00:01,  1.65it/s]
# epoch 003 | valid on 'valid' subset:  88% 7/8 [00:04<00:00,  1.55it/s]
# epoch 003 | valid on 'valid' subset: 100% 8/8 [00:05<00:00,  1.43it/s]
#                                                                       2023-11-24 12:46:18 | INFO | valid | epoch 003 | valid on 'valid' subset | loss 2.968 | ppl 7.83 | wps 2783.9 | wpb 1768.6 | bsz 126 | num_updates 681 | best_loss 2.968
# 2023-11-24 12:46:18 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 3 @ 681 updates
# 2023-11-24 12:46:18 | INFO | fairseq.trainer | Saving checkpoint to /content/checkpoints/checkpoint3.pt
# 2023-11-24 12:46:18 | INFO | fairseq.trainer | Finished saving checkpoint to /content/checkpoints/checkpoint3.pt
# 2023-11-24 12:46:18 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint3.pt (epoch 3 @ 681 updates, score 2.968) (writing took 0.5614119550000396 seconds)
# 2023-11-24 12:46:18 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2023-11-24 12:46:18 | INFO | train | epoch 003 | loss 3.24 | ppl 9.45 | wps 1087.1 | ups 0.61 | wpb 1790.9 | bsz 127.8 | num_updates 681 | lr 0.0005 | gnorm 1.142 | train_wall 366 | wall 1120
# 2023-11-24 12:46:18 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 12:46:18 | INFO | fairseq.data.iterators | grouped total_num_itrs = 227
# epoch 004:   0% 0/227 [00:00<?, ?it/s]2023-11-24 12:46:18 | INFO | fairseq.trainer | begin training epoch 4
# 2023-11-24 12:46:18 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 004: 100% 226/227 [06:07<00:01,  1.71s/it, loss=2.71, ppl=6.54, wps=1110.7, ups=0.62, wpb=1800.7, bsz=128, num_updates=900, lr=0.0005, gnorm=1.116, train_wall=161, wall=1475]2023-11-24 12:52:27 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-11-24 12:52:27 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
#
# epoch 004 | valid on 'valid' subset:   0% 0/8 [00:00<?, ?it/s]
# epoch 004 | valid on 'valid' subset:  12% 1/8 [00:00<00:02,  2.46it/s]
# epoch 004 | valid on 'valid' subset:  25% 2/8 [00:00<00:02,  2.45it/s]
# epoch 004 | valid on 'valid' subset:  38% 3/8 [00:01<00:02,  2.50it/s]
# epoch 004 | valid on 'valid' subset:  50% 4/8 [00:01<00:01,  2.38it/s]
# epoch 004 | valid on 'valid' subset:  62% 5/8 [00:02<00:01,  2.28it/s]
# epoch 004 | valid on 'valid' subset:  75% 6/8 [00:02<00:00,  2.06it/s]
# epoch 004 | valid on 'valid' subset:  88% 7/8 [00:03<00:00,  1.65it/s]
# epoch 004 | valid on 'valid' subset: 100% 8/8 [00:04<00:00,  1.25it/s]
#                                                                       2023-11-24 12:52:31 | INFO | valid | epoch 004 | valid on 'valid' subset | loss 2.721 | ppl 6.59 | wps 2970.3 | wpb 1768.6 | bsz 126 | num_updates 908 | best_loss 2.721
# 2023-11-24 12:52:31 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 4 @ 908 updates
# 2023-11-24 12:52:31 | INFO | fairseq.trainer | Saving checkpoint to /content/checkpoints/checkpoint4.pt
# 2023-11-24 12:52:32 | INFO | fairseq.trainer | Finished saving checkpoint to /content/checkpoints/checkpoint4.pt
# 2023-11-24 12:52:36 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint4.pt (epoch 4 @ 908 updates, score 2.721) (writing took 4.150451145000261 seconds)
# 2023-11-24 12:52:36 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2023-11-24 12:52:36 | INFO | train | epoch 004 | loss 2.731 | ppl 6.64 | wps 1077.7 | ups 0.6 | wpb 1790.9 | bsz 127.8 | num_updates 908 | lr 0.0005 | gnorm 1.106 | train_wall 366 | wall 1497
# 2023-11-24 12:52:36 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 12:52:36 | INFO | fairseq.data.iterators | grouped total_num_itrs = 227
# epoch 005:   0% 0/227 [00:00<?, ?it/s]2023-11-24 12:52:36 | INFO | fairseq.trainer | begin training epoch 5
# 2023-11-24 12:52:36 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 005: 100% 226/227 [06:02<00:02,  2.32s/it, loss=2.372, ppl=5.18, wps=1137.3, ups=0.62, wpb=1843.5, bsz=128, num_updates=1100, lr=0.0005, gnorm=1.084, train_wall=161, wall=1801]2023-11-24 12:58:40 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-11-24 12:58:40 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
#
# epoch 005 | valid on 'valid' subset:   0% 0/8 [00:00<?, ?it/s]
# epoch 005 | valid on 'valid' subset:  12% 1/8 [00:00<00:02,  2.35it/s]
# epoch 005 | valid on 'valid' subset:  25% 2/8 [00:00<00:02,  2.19it/s]
# epoch 005 | valid on 'valid' subset:  38% 3/8 [00:01<00:02,  2.22it/s]
# epoch 005 | valid on 'valid' subset:  50% 4/8 [00:01<00:01,  2.03it/s]
# epoch 005 | valid on 'valid' subset:  62% 5/8 [00:02<00:01,  2.03it/s]
# epoch 005 | valid on 'valid' subset:  75% 6/8 [00:03<00:01,  1.84it/s]
# epoch 005 | valid on 'valid' subset:  88% 7/8 [00:03<00:00,  1.70it/s]
# epoch 005 | valid on 'valid' subset: 100% 8/8 [00:04<00:00,  1.52it/s]
#                                                                       2023-11-24 12:58:44 | INFO | valid | epoch 005 | valid on 'valid' subset | loss 2.626 | ppl 6.17 | wps 3157.8 | wpb 1768.6 | bsz 126 | num_updates 1135 | best_loss 2.626
# 2023-11-24 12:58:44 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 5 @ 1135 updates
# 2023-11-24 12:58:44 | INFO | fairseq.trainer | Saving checkpoint to /content/checkpoints/checkpoint5.pt
# 2023-11-24 12:58:45 | INFO | fairseq.trainer | Finished saving checkpoint to /content/checkpoints/checkpoint5.pt
# 2023-11-24 12:58:45 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint5.pt (epoch 5 @ 1135 updates, score 2.626) (writing took 0.6430705269999635 seconds)
# 2023-11-24 12:58:45 | INFO | fairseq_cli.train | end of epoch 5 (average epoch stats below)
# 2023-11-24 12:58:45 | INFO | train | epoch 005 | loss 2.36 | ppl 5.13 | wps 1100.1 | ups 0.61 | wpb 1790.9 | bsz 127.8 | num_updates 1135 | lr 0.0005 | gnorm 1.105 | train_wall 362 | wall 1866
# 2023-11-24 12:58:45 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 12:58:45 | INFO | fairseq.data.iterators | grouped total_num_itrs = 227
# epoch 006:   0% 0/227 [00:00<?, ?it/s]2023-11-24 12:58:45 | INFO | fairseq.trainer | begin training epoch 6
# 2023-11-24 12:58:45 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 006: 100% 226/227 [06:06<00:01,  1.43s/it, loss=2.088, ppl=4.25, wps=1125.7, ups=0.62, wpb=1807.6, bsz=128, num_updates=1300, lr=0.0005, gnorm=1.171, train_wall=160, wall=2133]2023-11-24 13:04:53 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-11-24 13:04:53 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
#
# epoch 006 | valid on 'valid' subset:   0% 0/8 [00:00<?, ?it/s]
# epoch 006 | valid on 'valid' subset:  12% 1/8 [00:00<00:04,  1.49it/s]
# epoch 006 | valid on 'valid' subset:  25% 2/8 [00:01<00:03,  1.50it/s]
# epoch 006 | valid on 'valid' subset:  38% 3/8 [00:01<00:03,  1.58it/s]
# epoch 006 | valid on 'valid' subset:  50% 4/8 [00:02<00:02,  1.43it/s]
# epoch 006 | valid on 'valid' subset:  62% 5/8 [00:03<00:02,  1.38it/s]
# epoch 006 | valid on 'valid' subset:  75% 6/8 [00:04<00:01,  1.26it/s]
# epoch 006 | valid on 'valid' subset:  88% 7/8 [00:05<00:00,  1.12it/s]
# epoch 006 | valid on 'valid' subset: 100% 8/8 [00:06<00:00,  1.02it/s]
#                                                                       2023-11-24 13:05:00 | INFO | valid | epoch 006 | valid on 'valid' subset | loss 2.542 | ppl 5.82 | wps 2147.8 | wpb 1768.6 | bsz 126 | num_updates 1362 | best_loss 2.542
# 2023-11-24 13:05:00 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 6 @ 1362 updates
# 2023-11-24 13:05:00 | INFO | fairseq.trainer | Saving checkpoint to /content/checkpoints/checkpoint6.pt
# 2023-11-24 13:05:00 | INFO | fairseq.trainer | Finished saving checkpoint to /content/checkpoints/checkpoint6.pt
# 2023-11-24 13:05:01 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint6.pt (epoch 6 @ 1362 updates, score 2.542) (writing took 0.6424597529994571 seconds)
# 2023-11-24 13:05:01 | INFO | fairseq_cli.train | end of epoch 6 (average epoch stats below)
# 2023-11-24 13:05:01 | INFO | train | epoch 006 | loss 2.097 | ppl 4.28 | wps 1082.4 | ups 0.6 | wpb 1790.9 | bsz 127.8 | num_updates 1362 | lr 0.0005 | gnorm 1.159 | train_wall 366 | wall 2242
# 2023-11-24 13:05:01 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 13:05:01 | INFO | fairseq.data.iterators | grouped total_num_itrs = 227
# epoch 007:   0% 0/227 [00:00<?, ?it/s]2023-11-24 13:05:01 | INFO | fairseq.trainer | begin training epoch 7
# 2023-11-24 13:05:01 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 007: 100% 226/227 [06:03<00:01,  1.70s/it, loss=1.863, ppl=3.64, wps=1095.8, ups=0.6, wpb=1829.8, bsz=127.4, num_updates=1500, lr=0.0005, gnorm=1.108, train_wall=166, wall=2468]2023-11-24 13:11:06 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-11-24 13:11:06 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
#
# epoch 007 | valid on 'valid' subset:   0% 0/8 [00:00<?, ?it/s]
# epoch 007 | valid on 'valid' subset:  12% 1/8 [00:00<00:03,  2.12it/s]
# epoch 007 | valid on 'valid' subset:  25% 2/8 [00:00<00:02,  2.13it/s]
# epoch 007 | valid on 'valid' subset:  38% 3/8 [00:01<00:02,  2.26it/s]
# epoch 007 | valid on 'valid' subset:  50% 4/8 [00:01<00:01,  2.15it/s]
# epoch 007 | valid on 'valid' subset:  62% 5/8 [00:02<00:01,  2.06it/s]
# epoch 007 | valid on 'valid' subset:  75% 6/8 [00:02<00:01,  1.89it/s]
# epoch 007 | valid on 'valid' subset:  88% 7/8 [00:03<00:00,  1.73it/s]
# epoch 007 | valid on 'valid' subset: 100% 8/8 [00:04<00:00,  1.53it/s]
#                                                                       2023-11-24 13:11:11 | INFO | valid | epoch 007 | valid on 'valid' subset | loss 2.533 | ppl 5.79 | wps 3232.9 | wpb 1768.6 | bsz 126 | num_updates 1589 | best_loss 2.533
# 2023-11-24 13:11:11 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 7 @ 1589 updates
# 2023-11-24 13:11:11 | INFO | fairseq.trainer | Saving checkpoint to /content/checkpoints/checkpoint7.pt
# 2023-11-24 13:11:11 | INFO | fairseq.trainer | Finished saving checkpoint to /content/checkpoints/checkpoint7.pt
# 2023-11-24 13:11:12 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint7.pt (epoch 7 @ 1589 updates, score 2.533) (writing took 1.2757631320000655 seconds)
# 2023-11-24 13:11:12 | INFO | fairseq_cli.train | end of epoch 7 (average epoch stats below)
# 2023-11-24 13:11:12 | INFO | train | epoch 007 | loss 1.841 | ppl 3.58 | wps 1095 | ups 0.61 | wpb 1790.9 | bsz 127.8 | num_updates 1589 | lr 0.0005 | gnorm 1.117 | train_wall 363 | wall 2613
# 2023-11-24 13:11:12 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 13:11:12 | INFO | fairseq.data.iterators | grouped total_num_itrs = 227
# epoch 008:   0% 0/227 [00:00<?, ?it/s]2023-11-24 13:11:12 | INFO | fairseq.trainer | begin training epoch 8
# 2023-11-24 13:11:12 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 008: 100% 226/227 [06:07<00:01,  1.90s/it, loss=1.677, ppl=3.2, wps=1109.2, ups=0.61, wpb=1805.9, bsz=128, num_updates=1800, lr=0.0005, gnorm=1.144, train_wall=162, wall=2956]2023-11-24 13:17:22 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-11-24 13:17:22 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
#
# epoch 008 | valid on 'valid' subset:   0% 0/8 [00:00<?, ?it/s]
# epoch 008 | valid on 'valid' subset:  12% 1/8 [00:00<00:04,  1.45it/s]
# epoch 008 | valid on 'valid' subset:  25% 2/8 [00:01<00:04,  1.46it/s]
# epoch 008 | valid on 'valid' subset:  38% 3/8 [00:01<00:03,  1.59it/s]
# epoch 008 | valid on 'valid' subset:  50% 4/8 [00:02<00:02,  1.72it/s]
# epoch 008 | valid on 'valid' subset:  62% 5/8 [00:02<00:01,  1.77it/s]
# epoch 008 | valid on 'valid' subset:  75% 6/8 [00:03<00:01,  1.70it/s]
# epoch 008 | valid on 'valid' subset:  88% 7/8 [00:04<00:00,  1.60it/s]
# epoch 008 | valid on 'valid' subset: 100% 8/8 [00:05<00:00,  1.48it/s]
#                                                                       2023-11-24 13:17:27 | INFO | valid | epoch 008 | valid on 'valid' subset | loss 2.514 | ppl 5.71 | wps 2942.9 | wpb 1768.6 | bsz 126 | num_updates 1816 | best_loss 2.514
# 2023-11-24 13:17:27 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 8 @ 1816 updates
# 2023-11-24 13:17:27 | INFO | fairseq.trainer | Saving checkpoint to /content/checkpoints/checkpoint8.pt
# 2023-11-24 13:17:27 | INFO | fairseq.trainer | Finished saving checkpoint to /content/checkpoints/checkpoint8.pt
# 2023-11-24 13:17:28 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint8.pt (epoch 8 @ 1816 updates, score 2.514) (writing took 0.5938674049994006 seconds)
# 2023-11-24 13:17:28 | INFO | fairseq_cli.train | end of epoch 8 (average epoch stats below)
# 2023-11-24 13:17:28 | INFO | train | epoch 008 | loss 1.642 | ppl 3.12 | wps 1082.1 | ups 0.6 | wpb 1790.9 | bsz 127.8 | num_updates 1816 | lr 0.0005 | gnorm 1.119 | train_wall 368 | wall 2989
# 2023-11-24 13:17:28 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 13:17:28 | INFO | fairseq.data.iterators | grouped total_num_itrs = 227
# epoch 009:   0% 0/227 [00:00<?, ?it/s]2023-11-24 13:17:28 | INFO | fairseq.trainer | begin training epoch 9
# 2023-11-24 13:17:28 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 009: 100% 226/227 [06:07<00:01,  1.31s/it, loss=1.498, ppl=2.83, wps=1117.2, ups=0.62, wpb=1811.5, bsz=128, num_updates=2000, lr=0.0005, gnorm=1.135, train_wall=161, wall=3290]2023-11-24 13:23:36 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-11-24 13:23:36 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
#
# epoch 009 | valid on 'valid' subset:   0% 0/8 [00:00<?, ?it/s]
# epoch 009 | valid on 'valid' subset:  12% 1/8 [00:00<00:02,  2.46it/s]
# epoch 009 | valid on 'valid' subset:  25% 2/8 [00:00<00:02,  2.35it/s]
# epoch 009 | valid on 'valid' subset:  38% 3/8 [00:01<00:02,  2.37it/s]
# epoch 009 | valid on 'valid' subset:  50% 4/8 [00:01<00:01,  2.26it/s]
# epoch 009 | valid on 'valid' subset:  62% 5/8 [00:02<00:01,  2.22it/s]
# epoch 009 | valid on 'valid' subset:  75% 6/8 [00:03<00:01,  1.73it/s]
# epoch 009 | valid on 'valid' subset:  88% 7/8 [00:04<00:00,  1.36it/s]
# epoch 009 | valid on 'valid' subset: 100% 8/8 [00:05<00:00,  1.15it/s]
#                                                                       2023-11-24 13:23:41 | INFO | valid | epoch 009 | valid on 'valid' subset | loss 2.554 | ppl 5.87 | wps 2673.6 | wpb 1768.6 | bsz 126 | num_updates 2043 | best_loss 2.514
# 2023-11-24 13:23:41 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 9 @ 2043 updates
# 2023-11-24 13:23:41 | INFO | fairseq.trainer | Saving checkpoint to /content/checkpoints/checkpoint9.pt
# 2023-11-24 13:23:41 | INFO | fairseq.trainer | Finished saving checkpoint to /content/checkpoints/checkpoint9.pt
# 2023-11-24 13:23:41 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint9.pt (epoch 9 @ 2043 updates, score 2.554) (writing took 0.5632630649997736 seconds)
# 2023-11-24 13:23:41 | INFO | fairseq_cli.train | end of epoch 9 (average epoch stats below)
# 2023-11-24 13:23:41 | INFO | train | epoch 009 | loss 1.463 | ppl 2.76 | wps 1087.7 | ups 0.61 | wpb 1790.9 | bsz 127.8 | num_updates 2043 | lr 0.0005 | gnorm 1.114 | train_wall 366 | wall 3363
# 2023-11-24 13:23:41 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 13:23:41 | INFO | fairseq.data.iterators | grouped total_num_itrs = 227
# epoch 010:   0% 0/227 [00:00<?, ?it/s]2023-11-24 13:23:41 | INFO | fairseq.trainer | begin training epoch 10
# 2023-11-24 13:23:41 | INFO | fairseq_cli.train | Start iterating over samples
# epoch 010: 100% 226/227 [06:09<00:02,  2.05s/it, loss=1.362, ppl=2.57, wps=1089.6, ups=0.59, wpb=1842.6, bsz=128, num_updates=2200, lr=0.0005, gnorm=1.131, train_wall=168, wall=3621]2023-11-24 13:29:52 | INFO | fairseq_cli.train | begin validation on "valid" subset
# 2023-11-24 13:29:52 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
#
# epoch 010 | valid on 'valid' subset:   0% 0/8 [00:00<?, ?it/s]
# epoch 010 | valid on 'valid' subset:  12% 1/8 [00:00<00:03,  2.30it/s]
# epoch 010 | valid on 'valid' subset:  25% 2/8 [00:00<00:02,  2.34it/s]
# epoch 010 | valid on 'valid' subset:  38% 3/8 [00:01<00:02,  2.38it/s]
# epoch 010 | valid on 'valid' subset:  50% 4/8 [00:01<00:01,  2.21it/s]
# epoch 010 | valid on 'valid' subset:  62% 5/8 [00:02<00:01,  2.17it/s]
# epoch 010 | valid on 'valid' subset:  75% 6/8 [00:02<00:01,  1.98it/s]
# epoch 010 | valid on 'valid' subset:  88% 7/8 [00:03<00:00,  1.77it/s]
# epoch 010 | valid on 'valid' subset: 100% 8/8 [00:04<00:00,  1.54it/s]
#                                                                       2023-11-24 13:29:56 | INFO | valid | epoch 010 | valid on 'valid' subset | loss 2.572 | ppl 5.94 | wps 3306.2 | wpb 1768.6 | bsz 126 | num_updates 2270 | best_loss 2.514
# 2023-11-24 13:29:56 | INFO | fairseq.checkpoint_utils | Preparing to save checkpoint for epoch 10 @ 2270 updates
# 2023-11-24 13:29:56 | INFO | fairseq.trainer | Saving checkpoint to /content/checkpoints/checkpoint10.pt
# 2023-11-24 13:29:56 | INFO | fairseq.trainer | Finished saving checkpoint to /content/checkpoints/checkpoint10.pt
# 2023-11-24 13:29:57 | INFO | fairseq.checkpoint_utils | Saved checkpoint checkpoints/checkpoint10.pt (epoch 10 @ 2270 updates, score 2.572) (writing took 0.46688208199975634 seconds)
# 2023-11-24 13:29:57 | INFO | fairseq_cli.train | end of epoch 10 (average epoch stats below)
# 2023-11-24 13:29:57 | INFO | train | epoch 010 | loss 1.319 | ppl 2.5 | wps 1083 | ups 0.6 | wpb 1790.9 | bsz 127.8 | num_updates 2270 | lr 0.0005 | gnorm 1.121 | train_wall 368 | wall 3738
# 2023-11-24 13:29:57 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-11-24 13:29:57 | INFO | fairseq_cli.train | done training in 3737.5 seconds

# %% [markdown]
# # Evaluate the model

# %%
# ckpt_best, beam=5
! fairseq-generate data-bin/multi30k.tokenized.de-en \
    --path checkpoints/checkpoint_best.pt \
    --batch-size 128 \
    --beam 5 \
    --seed 1 \
    --scoring bleu \
    --wandb-project "Multi 30K En to De Translation"
# Out:
# Streaming output truncated to the last 5000 lines.
# D-279	-0.3997049331665039	girl playing a game outside .
# P-279	-0.3944 -0.2495 -1.7408 -0.1130 -0.1305 -0.1697 -0.0000
# S-342	ein radfahrer fährt einer <unk> hinauf .
# T-342	a cyclist riding up a grassy dirt trail .
# H-342	-0.89820796251297	a cyclist is riding a bike race .
# D-342	-0.89820796251297	a cyclist is riding a bike race .
# P-342	-0.0657 -1.8332 -0.3939 -0.8106 -0.0730 -1.2386 -2.8078 -0.8609 -0.0000
# S-281	dieser surfer versucht , nicht <unk> .
# T-281	this surfer is trying to avoid wiping out .
# H-281	-0.5625184774398804	this surfer is trying to make a surfer .
# D-281	-0.5625184774398804	this surfer is trying to make a surfer .
# P-281	-0.0074 -0.1162 -0.0833 -1.0527 -0.3249 -0.9452 -1.7639 -1.0074 -0.3240 -0.0001
# S-232	mann im wasser auf einem winzigen segelboot
# T-232	man in the water on a tiny sail boat
# H-232	-0.6790001392364502	man in the water on a tiny sailboat .
# D-232	-0.6790001392364502	man in the water on a tiny sailboat .
# P-232	-0.0519 -0.3089 -3.2515 -0.1037 -0.0855 -0.0536 -2.2090 -0.4669 -0.2588 -0.0003
# S-81	ein hund im wasser bei sonnenuntergang .
# T-81	a dog in the water overlooking a sunset .
# H-81	-0.14223921298980713	a dog in the water at sunset .
# D-81	-0.14223921298980713	a dog in the water at sunset .
# P-81	-0.0863 -0.0008 -0.4642 -0.3914 -0.0221 -0.1920 -0.0620 -0.0612 -0.0001
# S-742	ein wasserfall mit einem großen felsen daneben
# T-742	a waterfall with large rocks next to it
# H-742	-0.5677164196968079	a waterfall with a large rock nearby .
# D-742	-0.5677164196968079	a waterfall with a large rock nearby .
# P-742	-0.0228 -0.0970 -2.5909 -0.0147 -0.2834 -0.3982 -1.3933 -0.3092 -0.0001
# S-559	ein <unk> fluss mit blaugrünem wasser .
# T-559	a rushing river with blue green water .
# H-559	-1.0692449808120728	a <unk> river with a blue and green river .
# D-559	-1.0692449808120728	a <unk> river with a blue and green river .
# P-559	-0.2364 -2.2580 -1.0776 -0.2396 -1.1627 -2.4534 -1.0147 -0.6376 -2.5301 -0.1515 -0.0001
# S-506	teams spielen rugby auf dem platz .
# T-506	teams playing a rugby match on the ground
# H-506	-0.7224772572517395	teams playing rugby in the field .
# D-506	-0.7224772572517395	teams playing rugby in the field .
# P-506	-1.5246 -0.8938 -0.5288 -0.5222 -1.4040 -0.5191 -0.3873 -0.0000
# S-325	eine gruppe menschen genießen den sonnenuntergang .
# T-325	a group of people contemplating a beautiful sunset
# H-325	-0.1700664758682251	a group of people enjoying the sunset .
# D-325	-0.1700664758682251	a group of people enjoying the sunset .
# P-325	-0.0369 -0.0133 -0.0147 -0.0006 -1.1918 -0.2188 -0.0185 -0.0360 -0.0000
# S-738	<unk> eines <unk> , im vordergrund felsen
# T-738	night shot of a <<unk>> sky with rocks in the foreground
# H-738	-0.912622332572937	law enforcement in the foreground of a rock formation .
# D-738	-0.912622332572937	law enforcement in the foreground of a rock formation .
# P-738	-4.4919 -0.0861 -2.7751 -0.4162 -0.0760 -0.2334 -0.1229 -0.0168 -1.5746 -0.2459 -0.0001
# S-267	vier radfahrer fahren in einer reihe .
# T-267	four cyclists are riding in a row .
# H-267	-0.418789267539978	four cyclists are riding in a line .
# D-267	-0.418789267539978	four cyclists are riding in a line .
# P-267	-0.0197 -1.3657 -0.6546 -1.0903 -0.3426 -0.0520 -0.1717 -0.0724 -0.0000
# S-960	ein schönes altes <unk> ist geparkt .
# T-960	beautiful old model car is parked .
# H-960	-1.052769422531128	a beautiful day is parked on old .
# D-960	-1.052769422531128	a beautiful day is parked on old .
# P-960	-0.6909 -0.1472 -2.8041 -0.9174 -0.0190 -1.2884 -2.5351 -1.0730 -0.0000
# S-946	eine <unk> schwingt den schläger <unk> .
# T-946	woman baseball player moving the bat hard
# H-946	-0.8418101668357849	a <unk> is swinging the bat .
# D-946	-0.8418101668357849	a <unk> is swinging the bat .
# P-946	-0.1812 -2.8007 -1.0946 -0.0142 -0.4608 -0.0775 -2.1055 -0.0000
# S-819	ein schmetterling sitzt auf mehreren <unk> .
# T-819	a butterfly <<unk>> on several <<unk>> .
# H-819	-0.8019601106643677	a butterfly sits on several stone steps .
# D-819	-0.8019601106643677	a butterfly sits on several stone steps .
# P-819	-0.0175 -0.1537 -0.5816 -0.1042 -1.2281 -3.3082 -1.7588 -0.0654 -0.0002
# S-744	zwei männer rennen auf dem fußballfeld .
# T-744	two men running on the football field
# H-744	-0.20223119854927063	two men are running on the soccer field .
# D-744	-0.20223119854927063	two men are running on the soccer field .
# P-744	-0.0093 -0.0471 -0.7455 -0.1602 -0.0644 -0.6413 -0.0477 -0.1005 -0.2063 -0.0000
# S-580	mehrere personen sind im u-bahnhof unterwegs .
# T-580	group of people walking on the subway
# H-580	-0.4878220856189728	a group of people are walking in the subway .
# D-580	-0.4878220856189728	a group of people are walking in the subway .
# P-580	-1.3799 -0.0211 -0.0069 -0.0167 -0.7647 -0.1513 -0.2228 -0.1400 -2.5848 -0.0779 -0.0000
# S-356	zwei frauen , die ein <unk> feiern
# T-356	two women celebrating a volleyball match
# H-356	-0.9343085885047913	two women celebrating a partying routine .
# D-356	-0.9343085885047913	two women celebrating a partying routine .
# P-356	-0.0105 -0.1226 -1.0914 -0.3147 -1.6663 -2.9955 -1.2733 -0.0001
# S-653	mann mit brille und rucksack am bahnhof
# T-653	man with glasses and backpack at the train station
# H-653	-0.4693858325481415	man with glasses and backpack at the train station
# D-653	-0.4693858325481415	man with glasses and backpack at the train station
# P-653	-0.1030 -0.0944 -0.0358 -0.0519 -0.1390 -0.8699 -1.5202 -0.0406 -0.0673 -1.7715
# S-434	blick auf das rote dach eines hauses
# T-434	the view of the red roof of a house
# H-434	-0.918937087059021	view of a red house on red house .
# D-434	-0.918937087059021	view of a red house on red house .
# P-434	-3.1027 -0.1030 -1.2158 -0.0009 -0.2752 -0.6300 -2.1556 -0.2151 -1.4911 -0.0000
# S-550	eine <unk> schwimmt auf einem gewässer .
# T-550	a <<unk>> duck is swimming in a body of water .
# H-550	-0.40284597873687744	a <unk> is swimming on a body of water .
# D-550	-0.40284597873687744	a <unk> is swimming on a body of water .
# P-550	-0.1052 -1.5590 -1.6310 -0.5130 -0.5011 -0.0076 -0.0205 -0.0005 -0.0015 -0.0918 -0.0000
# S-102	mehrere menschen und hunde in einem park
# T-102	a group of people and dogs are in a park .
# H-102	-0.2608504593372345	several people and dogs in a park .
# D-102	-0.2608504593372345	several people and dogs in a park .
# P-102	-0.4293 -0.2103 -0.0203 -0.0142 -0.5103 -0.0124 -0.0001 -1.1506 -0.0001
# S-1013	eine leere bushaltestelle mit einem <unk> mülleimer
# T-1013	an empty bus stop with a <<unk>> trash can .
# H-1013	-0.8572180867195129	a bus stop with an empty trashcan .
# D-1013	-0.8572180867195129	a bus stop with an empty trashcan .
# P-1013	-3.2198 -0.0878 -0.5719 -0.1430 -0.0294 -0.7008 -2.0400 -0.9208 -0.0015
# S-594	zwei hohe <unk> mitten in einer <unk>
# T-594	two high <<unk>> in the middle of a water <<unk>>
# H-594	-0.823268473148346	two high <unk> in the middle of a high class .
# D-594	-0.823268473148346	two high <unk> in the middle of a high class .
# P-594	-0.0080 -0.4101 -2.3288 -1.0745 -0.4335 -0.0282 -0.0083 -0.1026 -0.2777 -4.0761 -1.1296 -0.0018
# S-398	bauarbeiter versuchen , eine leuchtreklame <unk> .
# T-398	construction workers try to put up a neon sign .
# H-398	-0.9139106273651123	construction workers are trying to use a <unk> .
# D-398	-0.9139106273651123	construction workers are trying to use a <unk> .
# P-398	-0.0784 -1.1407 -0.9351 -0.2451 -0.0055 -3.8856 -0.0448 -1.8814 -0.9223 -0.0001
# S-368	drei <unk> , umgeben von grünem <unk>
# T-368	there is three <<unk>> with green <<unk>> around them .
# H-368	-0.8515596985816956	three <unk> , three green , surrounded by green <unk> .
# D-368	-0.8515596985816956	three <unk> , three green , surrounded by green <unk> .
# P-368	-0.0145 -1.6313 -2.2728 -0.2448 -0.2063 -1.5735 -1.4508 -0.0008 -0.0242 -1.8718 -0.9279 -0.0001
# S-296	ein fußballspieler greift seinen gegner an .
# T-296	a soccer player makes a move against his opponent .
# H-296	-0.4486083686351776	a soccer player reaches for his opponent .
# D-296	-0.4486083686351776	a soccer player reaches for his opponent .
# P-296	-0.1447 -0.1745 -0.0228 -0.6164 -1.1911 -0.7975 -0.0852 -1.0052 -0.0001
# S-1002	drei <unk> mit <unk> auf einem sims
# T-1002	three wine glasses with wine sitting outside on ledge
# H-1002	-0.878939151763916	three <unk> are using a ledge on a ledge .
# D-1002	-0.878939151763916	three <unk> are using a ledge on a ledge .
# P-1002	-0.0271 -1.5999 -3.0604 -2.0130 -0.0748 -0.6147 -0.1317 -0.4272 -0.1313 -1.5880 -0.0002
# S-976	ein paar <unk> auf einem blauen untergrund
# T-976	a group of <<unk>> sitting on a blue background
# H-976	-0.8045321106910706	a couple of <unk> on a blue and green field .
# D-976	-0.8045321106910706	a couple of <unk> on a blue and green field .
# P-976	-0.0528 -0.0138 -0.5346 -3.4219 -0.9066 -0.0163 -0.0063 -0.5016 -0.9310 -2.6938 -0.5757 -0.0000
# S-870	zwei frauen sitzen vor einem spiegel .
# T-870	two woman sitting in front of a mirror .
# H-870	-0.1709381490945816	two women sitting in front of a mirror .
# D-870	-0.1709381490945816	two women sitting in front of a mirror .
# P-870	-0.0054 -0.2535 -1.1578 -0.1528 -0.0172 -0.0009 -0.0124 -0.0016 -0.1077 -0.0000
# S-805	nahaufnahme einer biene auf rosafarbenen blumen .
# T-805	a closeup of a bee on pink flowers .
# H-805	-0.5921564102172852	closeup of a bee pink flowers .
# D-805	-0.5921564102172852	closeup of a bee pink flowers .
# P-805	-0.0837 -0.1718 -0.8089 -1.4808 -0.8700 -0.0735 -1.2486 -0.0001
# S-732	zwei <unk> mit <unk> im wasser .
# T-732	two water <<unk>> flying kite <<unk>> in water .
# H-732	-0.7180300951004028	two rafts with water in the water .
# D-732	-0.7180300951004028	two rafts with water in the water .
# P-732	-0.0059 -4.0242 -1.5713 -0.1120 -0.4162 -0.0991 -0.1640 -0.0695 -0.0003
# S-664	ein feuerwehrwagen parkt auf einer straße .
# T-664	a fire truck is parked on a street .
# H-664	-0.2899358868598938	a firetruck is parked on a road .
# D-664	-0.2899358868598938	a firetruck is parked on a road .
# P-664	-0.0071 -0.8087 -1.1260 -0.0199 -0.0093 -0.1560 -0.4657 -0.0168 -0.0000
# S-227	drei leute mit surfbrettern am strand .
# T-227	three people with surfboards on the shore of the beach
# H-227	-0.6638031005859375	three people on the beach with rocks on the beach .
# D-227	-0.6638031005859375	three people on the beach with rocks on the beach .
# P-227	-0.0290 -0.0014 -0.7276 -0.7069 -0.0070 -0.0275 -4.3675 -0.8779 -0.8398 -0.3272 -0.0538 -0.0000
# S-322	ein hund rennt am strand .
# T-322	a dog running on the shore of the beach
# H-322	-0.2326366901397705	a dog running on the beach .
# D-322	-0.2326366901397705	a dog running on the beach .
# P-322	-0.0220 -0.0006 -0.8819 -0.0681 -0.3727 -0.0064 -0.5094 -0.0000
# S-927	<unk> <unk> setzt <unk> ab .
# T-927	yellow and red <<unk>> airplane dropping water .
# H-927	-1.266643762588501	the <unk> is sitting down .
# D-927	-1.266643762588501	the <unk> is sitting down .
# P-927	-3.8399 -1.5227 -1.7364 -0.7761 -0.0196 -0.9716 -0.0002
# S-855	feuerwerk über einem see bei nacht
# T-855	view of fireworks and a lake at night
# H-855	-0.6532084941864014	fireworks over a lake at night .
# D-855	-0.6532084941864014	fireworks over a lake at night .
# P-855	-2.4002 -1.9320 -0.3927 -0.0052 -0.0845 -0.1486 -0.2621 -0.0004
# S-833	mehrere kinder lächeln und tanzen .
# T-833	a group of young children are smiling and dancing .
# H-833	-0.49251794815063477	several children smiling and dancing .
# D-833	-0.49251794815063477	several children smiling and dancing .
# P-833	-0.1379 -0.4275 -1.3819 -0.2035 -0.1014 -1.1954 -0.0000
# S-854	ein paar kinder machen sport .
# T-854	a bunch of little kids are exercising .
# H-854	-0.5790618062019348	some children are performing a sport .
# D-854	-0.5790618062019348	some children are performing a sport .
# P-854	-1.6101 -0.4273 -0.1531 -1.4995 -0.9017 -0.0223 -0.0187 -0.0000
# S-503	kinder mit <unk> und roten <unk>
# T-503	young kids with clown makeup and red noses
# H-503	-1.3045668601989746	children with red and red <unk> with red plastic hair .
# D-503	-1.3045668601989746	children with red and red <unk> with red plastic hair .
# P-503	-0.6774 -0.4392 -0.0043 -0.5139 -0.0456 -3.0824 -2.7872 -0.1496 -2.5827 -3.3496 -2.0227 -0.0001
# S-420	einsame straße mitten in der wüste
# T-420	desolate road in the middle of the desert
# H-420	-0.5627713203430176	lone person in the desert in the desert
# D-420	-0.5627713203430176	lone person in the desert in the desert
# P-420	-0.0522 -3.3109 -0.0560 -0.0056 -0.4625 -0.1537 -0.0077 -0.1537 -0.8625
# S-795	nahaufnahme einer gitarre mit den saiten
# T-795	guitar close up view with its ropes
# H-795	-0.7119990587234497	closeup of a guitar with a guitar
# D-795	-0.7119990587234497	closeup of a guitar with a guitar
# P-795	-0.3031 -0.1599 -0.6910 -0.3380 -1.6160 -0.8879 -0.2218 -1.4781
# S-453	blick auf mehrere gebäude mit <unk>
# T-453	view of several buildings with glass windows
# H-453	-0.6365129351615906	view of a building overlooking a building .
# D-453	-0.6365129351615906	view of a building overlooking a building .
# P-453	-1.7745 -0.1838 -0.5912 -0.0204 -1.1655 -0.6147 -0.2918 -1.0842 -0.0025
# S-818	football spielende männer auf dem spielfeld
# T-818	men playing football on the pitch
# H-818	-0.7671176195144653	men playing football on the court .
# D-818	-0.7671176195144653	men playing football on the court .
# P-818	-2.1841 -1.1058 -0.0214 -0.0417 -0.5866 -1.7510 -0.4462 -0.0001
# S-951	a mädchen hält eine <unk> .
# T-951	a girl holds a sunflower
# H-951	-0.39797869324684143	a young girl is holding a <unk> .
# D-951	-0.39797869324684143	a young girl is holding a <unk> .
# P-951	-0.0583 -1.1292 -0.0820 -1.0242 -0.0096 -0.0117 -0.8195 -0.4472 -0.0000
# S-962	ein roter vogel auf einem zweig
# T-962	a red bird on the branch of a tree
# H-962	-0.5261686444282532	a red bird on a tree branch
# D-962	-0.5261686444282532	a red bird on a tree branch
# P-962	-0.0924 -0.0051 -0.0130 -2.4145 -0.0312 -0.7766 -0.0679 -0.8088
# S-701	foto eines schönen sonnenuntergangs mit palmen
# T-701	photo of a beautiful sunset full of palm trees
# H-701	-0.35073620080947876	photo of a beautiful sunset with palm trees .
# D-701	-0.35073620080947876	photo of a beautiful sunset with palm trees .
# P-701	-1.0133 -0.0466 -0.0564 -0.2916 -0.7517 -0.1365 -0.4092 -0.2103 -0.5913 -0.0006
# S-1004	mehrere hohe gebäude in schwarz-weiß .
# T-1004	a group of tall buildings is shown in black and white .
# H-1004	-0.7416207194328308	several tall , and white , are walking in black and white building .
# D-1004	-0.7416207194328308	several tall , and white , are walking in black and white building .
# P-1004	-0.2222 -0.1737 -2.0142 -2.4224 -0.4230 -0.5042 -0.7738 -1.3495 -0.3182 -1.0290 -0.1652 -0.1801 -1.5052 -0.0435 -0.0000
# S-344	mehrere mädchen spielen volleyball gegeneinander .
# T-344	a group of girls are playing against each other in volleyball .
# H-344	-0.5649321675300598	several girls are competing to play volleyball .
# D-344	-0.5649321675300598	several girls are competing to play volleyball .
# P-344	-0.3336 -0.0207 -1.3238 -0.8334 -1.8069 -0.2477 -0.4262 -0.0921 -0.0000
# S-830	nächtliche <unk> am ufer eines flusses
# T-830	night view of a city on the <<unk>> of a river
# H-830	-0.5219166278839111	at the edge of a river at the bank of a river .
# D-830	-0.5219166278839111	at the edge of a river at the bank of a river .
# P-830	-1.7973 -0.3088 -1.3451 -0.3814 -0.1475 -0.0859 -0.9924 -0.2882 -1.5001 -0.0288 -0.1640 -0.1066 -0.1606 -0.0002
# S-395	eine <unk> einer hütte im wald
# T-395	a black and white picture of a cabin in the woods
# H-395	-0.955065131187439	a cabin shot of a hut in the woods .
# D-395	-0.955065131187439	a cabin shot of a hut in the woods .
# P-395	-0.0550 -3.7007 -3.2831 -0.2431 -0.0195 -1.2029 -0.6961 -0.2081 -0.8297 -0.2672 -0.0003
# S-370	ein <unk> eines <unk> im schnee
# T-370	a paw print of an animal is in the snow .
# H-370	-1.0586224794387817	a <unk> of a <unk> in the snow .
# D-370	-1.0586224794387817	a <unk> of a <unk> in the snow .
# P-370	-0.1119 -1.8263 -4.3173 -0.3890 -2.5226 -0.7713 -0.0255 -0.0036 -0.6185 -0.0002
# S-352	ein <unk> an einem klaren herbsttag
# T-352	a mountain lake in the fall on a clear day .
# H-352	-0.7650408148765564	a <unk> on an autumn day at an autumn day .
# D-352	-0.7650408148765564	a <unk> on an autumn day at an autumn day .
# P-352	-0.6708 -0.7948 -3.1044 -0.1784 -0.1178 -0.0095 -2.8824 -0.2546 -0.1140 -0.1477 -0.8977 -0.0081
# S-526	drei männer in sportbekleidung beim <unk>
# T-526	three men running wearing sport <<unk>> in a obstacle race
# H-526	-1.08809232711792	three men in military uniforms are watching as they are being <unk> .
# D-526	-1.08809232711792	three men in military uniforms are watching as they are being <unk> .
# P-526	-0.0527 -0.0197 -0.4099 -4.0511 -0.7975 -1.0420 -1.6407 -2.3902 -0.8912 -1.1910 -1.7419 -0.8266 -0.1787 -0.0000
# S-234	fünf <unk> <unk> vor einem <unk>
# T-234	there are five <<unk>> running in front of a leopard
# H-234	-1.3389443159103394	five college five college school children in front of a <unk> tent .
# D-234	-1.3389443159103394	five college five college school children in front of a <unk> tent .
# P-234	-0.0067 -2.2679 -1.0071 -2.6738 -3.3260 -2.9557 -0.8052 -0.0007 -0.0023 -0.2498 -2.3248 -2.9702 -0.1543 -0.0006
# S-586	drei fußballspieler mitten im spiel
# T-586	three soccer players are in the middle of a game .
# H-586	-0.3302975594997406	three soccer players in the middle of the game
# D-586	-0.3302975594997406	three soccer players in the middle of the game
# P-586	-0.1746 -0.0322 -0.0052 -0.5261 -0.2808 -0.0744 -0.0118 -0.6127 -0.6352 -0.9497
# S-926	eine <unk> durch <unk> hindurch
# T-926	a city <<unk>> in back of several metal pipes .
# H-926	-1.4750348329544067	a female athlete through a sand sculpture .
# D-926	-1.4750348329544067	a female athlete through a sand sculpture .
# P-926	-0.1877 -2.4773 -2.3835 -0.7869 -0.4785 -4.0141 -2.7401 -0.2070 -0.0002
# S-525	zwei lacrosse-spieler in einem spiel
# T-525	the two lacrosse players are playing in a match .
# H-525	-0.5550849437713623	two lacrosse players in a game .
# D-525	-0.5550849437713623	two lacrosse players in a game .
# P-525	-0.0210 -2.5786 -0.0201 -0.9625 -0.0198 -0.1181 -0.7206 -0.0000
# S-760	ein <unk> einer landschaft .
# T-760	a black and white photo of a hillside .
# H-760	-0.8909872770309448	a <unk> landscape .
# D-760	-0.8909872770309448	a <unk> landscape .
# P-760	-0.0494 -3.5929 -0.2128 -0.5990 -0.0009
# S-792	mehrere männer bei einem <unk>
# T-792	a group of men in a canoe race
# H-792	-0.9805452227592468	several men involved in a karate competition .
# D-792	-0.9805452227592468	several men involved in a karate competition .
# P-792	-0.1858 -0.0110 -3.9346 -0.0610 -0.1856 -4.0087 -0.3461 -0.0920 -0.0000
# S-304	ein mann fährt mountainbike .
# T-304	there is a man riding a mountain bike
# H-304	-0.2066817432641983	a man riding a mountain bike .
# D-304	-0.2066817432641983	a man riding a mountain bike .
# P-304	-0.0621 -0.0098 -1.3968 -0.0411 -0.0297 -0.0177 -0.0962 -0.0000
# S-336	zwei frauen spielen <unk> .
# T-336	a couple of women playing beach volleyball
# H-336	-0.6520225405693054	two women play <unk> .
# D-336	-0.6520225405693054	two women play <unk> .
# P-336	-0.0171 -0.4270 -0.5452 -1.3758 -1.5471 -0.0000
# S-371	drei männer fahren fahrrad .
# T-371	three men ride bikes .
# H-371	-0.42483097314834595	three men are riding a bike .
# D-371	-0.42483097314834595	three men are riding a bike .
# P-371	-0.0388 -0.0143 -1.0505 -0.0877 -1.3448 -0.8217 -0.0408 -0.0000
# S-354	ein roter <unk> .
# T-354	a red stone lighthouse tower .
# H-354	-0.8971062898635864	a red convertible is <unk> .
# D-354	-0.8971062898635864	a red convertible is <unk> .
# P-354	-0.0838 -0.0024 -4.1577 -0.1167 -1.8875 -0.0317 -0.0000
# S-974	berglandschaft und grüne <unk>
# T-974	mountain landscape and green <<unk>>
# H-974	-1.0064040422439575	green and gray mountain landscape .
# D-974	-1.0064040422439575	green and gray mountain landscape .
# P-974	-0.1898 -0.0039 -2.4028 -1.8360 -1.6913 -0.9209 -0.0001
#  11% 1/9 [00:03<00:29,  3.73s/it, wps=345]S-848	fünf pferde und jockeys nehmen an einem rennen teil .
# T-848	five horses and jockeys participating in a race .
# H-848	-0.17400029301643372	five horses and jockeys participating in a race .
# D-848	-0.17400029301643372	five horses and jockeys participating in a race .
# P-848	-0.0818 -0.3667 -0.0143 -0.0499 -1.1076 -0.0178 -0.0187 -0.0040 -0.0792 -0.0000
# S-572	ein riesiger dschungel mit ein paar häusern in der ferne
# T-572	giant jungle with some houses at the end
# H-572	-1.0614324808120728	a few people with a jungle colored houses in the distance .
# D-572	-1.0614324808120728	a few people with a jungle colored houses in the distance .
# P-572	-0.1708 -3.6336 -2.9007 -0.5189 -1.1252 -0.1963 -3.5365 -0.5526 -0.6759 -0.0250 -0.0050 -0.4578 -0.0001
# S-628	ein weißer vogel fliegt in der nähe von bäumen .
# T-628	a white bird is flying by trees .
# H-628	-0.16065023839473724	a white bird flies near some trees .
# D-628	-0.16065023839473724	a white bird flies near some trees .
# P-628	-0.1506 -0.0009 -0.0024 -0.1190 -0.1515 -0.9438 -0.0443 -0.0334 -0.0000
# S-752	eine <unk> , die zwischen ästen und <unk> schwimmt .
# T-752	a lizard swimming around branches and weeds .
# H-752	-1.2147390842437744	a <unk> is swimming between rocks and <unk> .
# D-752	-1.2147390842437744	a <unk> is swimming between rocks and <unk> .
# P-752	-0.2509 -1.5754 -2.9951 -0.1687 -0.0899 -4.0857 -0.0143 -2.5241 -0.4432 -0.0001
# S-915	zwei sitzende männer blicken auf notizen in einem notizbuch .
# T-915	two men sitting watching notes in a notebook
# H-915	-0.5144662857055664	two seated men are looking at notes in a notebook .
# D-915	-0.5144662857055664	two seated men are looking at notes in a notebook .
# P-915	-0.0043 -3.0087 -0.0466 -0.7935 -0.3212 -0.1825 -0.5141 -0.4743 -0.0214 -0.3753 -0.4314 -0.0002
# S-937	eine schöne landschaft mit einem bauernhof und <unk> wiese .
# T-937	beautiful landscape of a farm and his meadow
# H-937	-0.5411598682403564	a beautiful view with a farm landscape and grass .
# D-937	-0.5411598682403564	a beautiful view with a farm landscape and grass .
# P-937	-0.1764 -0.1908 -0.9224 -0.9326 -0.0202 -0.3848 -1.4818 -0.0407 -1.5265 -0.2759 -0.0007
# S-407	goldene blätter fallen von einem baum auf den gehweg .
# T-407	golden leaves falling off a tree onto a <<unk>>
# H-407	-0.8670060634613037	the <unk> of the birds on a sidewalk .
# D-407	-0.8670060634613037	the <unk> of the birds on a sidewalk .
# P-407	-1.0496 -1.9221 -0.5234 -0.8678 -1.6664 -1.4775 -0.2296 -0.4480 -0.4855 -0.0002
# S-419	foto eines schönen sonnenuntergangs mit wolken , umgeben von häusern
# T-419	photo of a beautiful cloud sunset surrounded by houses
# H-419	-0.826434314250946	photo of a beautiful sunset with clouds in the clouds .
# D-419	-0.826434314250946	photo of a beautiful sunset with clouds in the clouds .
# P-419	-1.8682 -0.0474 -0.3160 -0.2020 -1.6260 -0.4583 -0.4725 -0.9061 -0.5519 -2.3824 -1.0862 -0.0001
# S-480	mann beim <unk> über einem blauen band auf der wiese
# T-480	male in the <<unk>> above blue strap on grass
# H-480	-0.9646475315093994	man in a blue and blue ribbon on a lawn chair in the grass .
# D-480	-0.9646475315093994	man in a blue and blue ribbon on a lawn chair in the grass .
# P-480	-0.0422 -2.5879 -0.1339 -0.0074 -2.2575 -0.4032 -2.5651 -0.5431 -0.4758 -1.8856 -1.1240 -1.9722 -0.3105 -0.8251 -0.3003 -0.0005
# S-777	person , die auf einer holzbrücke über dem fluss steht
# T-777	person standing on a wooden bridge over the river
# H-777	-0.28254467248916626	person standing on a wooden bridge over the river .
# D-777	-0.28254467248916626	person standing on a wooden bridge over the river .
# P-777	-0.1336 -0.0436 -0.8260 -0.0886 -0.2726 -0.8607 -0.4553 -0.2834 -0.0184 -0.1256 -0.0001
# S-832	<unk> sind ganz darauf konzentriert , einander <unk> <unk> .
# T-832	<<unk>> are busy throwing pins to each other .
# H-832	-1.3937078714370728	two <unk> are focused on one is focused .
# D-832	-1.3937078714370728	two <unk> are focused on one is focused .
# P-832	-2.9972 -3.0269 -1.3351 -0.4380 -0.0962 -1.7130 -1.9438 -1.1391 -1.2469 -0.0008
# S-235	ein <unk> gekleideter mountainbiker fährt auf der rennstrecke .
# T-235	a dirt biker in yellow and blue rides through the course .
# H-235	-0.4411669373512268	a mountain biker rides on the track .
# D-235	-0.4411669373512268	a mountain biker rides on the track .
# P-235	-0.1182 -0.1750 -0.1249 -2.3689 -0.3590 -0.1449 -0.4685 -0.2112 -0.0000
# S-689	farbenfrohe <unk> , an einem steinigen strand aufgestellt .
# T-689	colorful swim <<unk>> stacked on the rocky shore of a beach .
# H-689	-0.7319323420524597	a group of people are picking up a rocky beach .
# D-689	-0.7319323420524597	a group of people are picking up a rocky beach .
# P-689	-2.5195 -0.7177 -0.0033 -1.1959 -1.5275 -2.1000 -0.0104 -0.5444 -0.0915 -0.0170 -0.0558 -0.0001
# S-355	oberhalb einer steintreppe befindet sich eine grüne tür .
# T-355	a green door is at the top of a rocky staircase .
# H-355	-0.6863822340965271	a green stairway over a door .
# D-355	-0.6863822340965271	a green stairway over a door .
# P-355	-0.0668 -0.5684 -1.4510 -2.7402 -0.1860 -0.4286 -0.0500 -0.0000
# S-374	ein kleines <unk> lugt hinter einem ast hervor .
# T-374	a tiny furry animal peeks out from behind a tree branch .
# H-374	-0.6052660346031189	a small tree branch behind a tree branch .
# D-374	-0.6052660346031189	a small tree branch behind a tree branch .
# P-374	-0.0251 -0.3530 -3.3000 -0.9135 -0.3406 -0.1285 -0.2891 -0.1794 -0.5234 -0.0001
# S-405	ein <unk> mit grün-weißem trikot wirft einen baseball .
# T-405	a baseball pitcher wearing a green and white uniform pitching a baseball
# H-405	-0.593406617641449	a baseball player wearing a green and white uniform is throwing a baseball .
# D-405	-0.593406617641449	a baseball player wearing a green and white uniform is throwing a baseball .
# P-405	-0.2867 -2.0187 -0.4782 -1.3999 -0.1385 -2.0938 -0.0136 -0.0882 -0.9915 -0.6942 -0.1157 -0.5207 -0.0093 -0.0520 -0.0000
# S-433	eine person mit orangefarbener jacke <unk> einen berg .
# T-433	a person in an orange jacket climbs up a mountain side .
# H-433	-0.5505470633506775	a person in an orange jacket with a mountain .
# D-433	-0.5505470633506775	a person in an orange jacket with a mountain .
# P-433	-0.3704 -0.0061 -2.2555 -0.1225 -0.0010 -0.0135 -2.2748 -0.2641 -0.1834 -0.5647 -0.0000
# S-491	eine frau wirft eine bowling-kugel auf eine <unk> .
# T-491	a woman is rolling a bowling ball down a bowling lane .
# H-491	-0.45055219531059265	a woman is throwing a bowling ball on a bowling alley .
# D-491	-0.45055219531059265	a woman is throwing a bowling ball on a bowling alley .
# P-491	-0.0977 -0.0381 -0.4815 -0.0791 -0.0890 -0.3047 -0.1278 -0.2198 -0.1742 -2.2325 -1.9965 -0.0160 -0.0001
# S-498	mehrere häuser stehen in einer reihe am ufer .
# T-498	a group of houses are lined up along the waters edge .
# H-498	-0.6871817708015442	several houses are lined up in a line by the shore .
# D-498	-0.6871817708015442	several houses are lined up in a line by the shore .
# P-498	-0.1922 -1.5118 -0.5933 -1.5639 -0.2208 -1.6730 -0.3280 -0.4720 -1.3961 -0.0393 -0.8481 -0.0947 -0.0002
# S-531	eine frau macht einen sprung mit gespreizten beinen .
# T-531	a woman is doing a leap with her legs spread apart .
# H-531	-0.43727266788482666	a woman makes a jump with her legs spread .
# D-531	-0.43727266788482666	a woman makes a jump with her legs spread .
# P-531	-0.1630 -0.0982 -2.1011 -0.0395 -0.3416 -0.1060 -0.9573 -0.1191 -0.7202 -0.1640 -0.0001
# S-535	ein <unk> <unk> einen ankommenden spieler mit <unk> .
# T-535	a baseball team high <<unk>> a player as he comes in .
# H-535	-1.2526209354400635	a soccer player is <unk> a player coming for the opposite team .
# D-535	-1.2526209354400635	a soccer player is <unk> a player coming for the opposite team .
# P-535	-0.3475 -2.3669 -0.3081 -1.5653 -2.4654 -1.1434 -0.2417 -1.4050 -1.8340 -1.0339 -3.1501 -0.7128 -0.9626 -0.0000
# S-544	ein mann auf einem motorrad bei einem überschlag .
# T-544	a man on a motorcycle in the middle of a flip .
# H-544	-0.8844117522239685	a man on a motorcycle is riding a beautiful .
# D-544	-0.8844117522239685	a man on a motorcycle is riding a beautiful .
# P-544	-0.1775 -0.0114 -0.2092 -0.0112 -0.7126 -1.0654 -2.3595 -0.0742 -3.6670 -1.4404 -0.0000
# S-654	ein see bei einem waldgebiet an einem sonnigen tag
# T-654	a lake next to a wooded area on a sunny day .
# H-654	-0.5436649918556213	a lake in a wooded area during a sunny day .
# D-654	-0.5436649918556213	a lake in a wooded area during a sunny day .
# P-654	-0.1222 -0.0134 -3.3221 -0.0580 -0.2643 -0.1226 -1.4477 -0.0287 -0.4126 -0.0002 -0.7309 -0.0012
# S-660	eine <unk> mit bäumen unter einem bewölkten himmel .
# T-660	a landscape of rolling hills and trees underneath a cloudy sky .
# H-660	-0.7533140778541565	a cloudy sky is under a cloudy sky .
# D-660	-0.7533140778541565	a cloudy sky is under a cloudy sky .
# P-660	-0.3246 -3.0173 -0.7565 -1.2833 -1.7363 -0.1455 -0.0127 -0.1816 -0.0750 -0.0004
# S-878	die lichter einer stadt am fluss bei nacht .
# T-878	a city lit up at night next to the river .
# H-878	-0.3419535756111145	the river at the river by the river .
# D-878	-0.3419535756111145	the river at the river by the river .
# P-878	-0.0089 -0.4303 -0.3398 -0.3135 -0.2606 -1.0850 -0.2722 -0.6115 -0.0974 -0.0003
# S-233	ein flauschiger braun-weißer hund springt durch einen hindernisparcours .
# T-233	a fluffy brown and white dog leaping through an obstacle course .
# H-233	-0.24365878105163574	a fluffy white and brown dog jumps through an obstacle course .
# D-233	-0.24365878105163574	a fluffy white and brown dog jumps through an obstacle course .
# P-233	-0.1214 -0.3252 -0.2925 -0.0120 -0.8447 -0.0171 -1.2599 -0.0979 -0.1065 -0.0144 -0.0374 -0.0385 -0.0001
# S-145	zwei personen gehen bei einem mülleimer auf einer straße
# T-145	two people walking down a street next to a trash can .
# H-145	-0.5643513798713684	two people walking on a street in a trashcan on a trashcan .
# D-145	-0.5643513798713684	two people walking on a street in a trashcan on a trashcan .
# P-145	-0.0056 -0.0167 -0.6787 -0.3320 -0.0459 -1.2575 -1.5337 -0.0290 -0.9420 -1.2279 -0.0700 -1.6330 -0.1284 -0.0004
# S-96	ein mann geht alleine vor einer kirche entlang .
# T-96	a man is walking by himself in front of a church .
# H-96	-0.11905267834663391	a man walking alone in front of a church .
# D-96	-0.11905267834663391	a man walking alone in front of a church .
# P-96	-0.1531 -0.0071 -0.7455 -0.0563 -0.3023 -0.0022 -0.0013 -0.0125 -0.0054 -0.0240 -0.0001
# S-48	sechs kinder unterschiedlicher <unk> stehen vor einem holzzaun .
# T-48	six children of different races stand in front of a wooden fence
# H-48	-0.21623530983924866	six children are standing in front of a wooden fence .
# D-48	-0.21623530983924866	six children are standing in front of a wooden fence .
# P-48	-0.0132 -0.7335 -0.3565 -0.2574 -0.2242 -0.0005 -0.0004 -0.5407 -0.0483 -0.0270 -0.3929 -0.0001
# S-33	ein hellbrauner hund zieht am schlauch eines <unk> .
# T-33	a tan dog tugs on a hose from a vacuum cleaner .
# H-33	-0.4422483444213867	a tan dog pulls on the edge of a hose .
# D-33	-0.4422483444213867	a tan dog pulls on the edge of a hose .
# P-33	-0.0617 -0.1779 -0.0125 -1.6692 -0.7713 -0.0597 -1.6671 -0.0004 -0.3145 -0.3114 -0.2612 -0.0000
# S-1053	in <unk> <unk> bild mehrerer oldtimer von vorne .
# T-1053	eye level view of the front of several antique cars .
# H-1053	-1.560912013053894	here is a picture of <unk> for a picture of people in the front of the <unk> .
# D-1053	-1.560912013053894	here is a picture of <unk> for a picture of people in the front of the <unk> .
# P-1053	-4.7513 -0.2703 -0.6936 -1.3839 -0.0031 -3.5067 -2.4352 -1.4647 -0.8699 -0.0407 -3.3217 -0.7172 -0.6230 -4.0678 -0.0167 -1.0772 -3.2825 -1.1313 -0.0006
# S-990	eine hand auf dem wasser mit bergen im hintergrund
# T-990	a hand on the water and some mountains in the background
# H-990	-0.2590450048446655	a hand on the water with mountains in the background .
# D-990	-0.2590450048446655	a hand on the water with mountains in the background .
# P-990	-0.1936 -0.0855 -0.2181 -0.6702 -0.1112 -0.1132 -1.1148 -0.0285 -0.2819 -0.0207 -0.2689 -0.0019
# S-958	ein mann mit einem roten schal fährt motorrad .
# T-958	a man wearing a red scarf is riding a motorcycle .
# H-958	-0.2932276427745819	a man with a red scarf is riding a motorcycle .
# D-958	-0.2932276427745819	a man with a red scarf is riding a motorcycle .
# P-958	-0.1696 -0.0081 -0.8213 -0.0019 -0.0006 -0.0404 -1.0795 -0.6765 -0.1163 -0.5766 -0.0280 -0.0000
# S-939	ein mädchen macht neben einem großen gewässer <unk> .
# T-939	a young girl stretches beside a large body of water .
# H-939	-0.25378620624542236	a girl makes a large body of water next to a large body of water .
# D-939	-0.25378620624542236	a girl makes a large body of water next to a large body of water .
# P-939	-0.0666 -0.0509 -2.0128 -0.1730 -0.1346 -0.0211 -0.0584 -0.0053 -1.3939 -0.0001 -0.0398 -0.2457 -0.0103 -0.0213 -0.0063 -0.0743 -0.0000
# S-930	ein mann steht alleine in einem schwarz-weißen flur .
# T-930	a man standing alone in a black and white hallway .
# H-930	-0.27024975419044495	a man is standing alone in a white hallway .
# D-930	-0.27024975419044495	a man is standing alone in a white hallway .
# P-930	-0.0814 -0.0080 -0.9692 -0.0388 -0.0112 -0.0230 -0.0073 -1.2125 -0.5941 -0.0271 -0.0001
# S-924	<unk> alter häuser in verschiedenen farben mit menschen davor
# T-924	structures of old houses of different colors and people in front
# H-924	-1.04496169090271	old people in different colors are walking with different colors .
# D-924	-1.04496169090271	old people in different colors are walking with different colors .
# P-924	-0.1472 -2.8793 -1.8572 -0.0664 -0.4986 -1.4183 -2.2632 -1.0299 -0.3769 -1.0336 -0.9687 -0.0002
# S-910	ein mann und eine frau posieren am eiffelturm .
# T-910	a man and a woman pose at the eiffel tower .
# H-910	-0.31607475876808167	a man and a woman pose on the eiffel tower .
# D-910	-0.31607475876808167	a man and a woman pose on the eiffel tower .
# P-910	-0.0865 -0.0125 -0.0008 -1.2414 -0.0958 -0.2841 -0.5175 -0.4166 -0.8158 -0.2649 -0.0568 -0.0000
# S-821	eine felswand in der wüste hinter mehreren grünen bäumen
# T-821	a rock cliff in the desert behind several green trees .
# H-821	-0.6457135081291199	a rock wall in the desert with several green desert .
# D-821	-0.6457135081291199	a rock wall in the desert with several green desert .
# P-821	-0.0535 -0.7600 -0.1053 -0.7100 -0.1293 -0.2923 -1.0980 -0.0844 -0.0640 -3.4875 -0.9640 -0.0002
# S-734	ein reh steht neben einem <unk> im gras .
# T-734	a deer stands in the grass next to a dead end sign .
# H-734	-0.6591375470161438	a deer standing next to a deer in the grass .
# D-734	-0.6591375470161438	a deer standing next to a deer in the grass .
# P-734	-0.0156 -0.2205 -0.7846 -1.8217 -0.0001 -0.2477 -2.2551 -1.1183 -1.2727 -0.0006 -0.1721 -0.0008
# S-551	bild einer hütte im wald bei <unk> und <unk>
# T-551	this image is of a cabin in the woods while the stars and the moon is out .
# H-551	-1.020890474319458	picture of a hut in the woods with a hut and woods .
# D-551	-1.020890474319458	picture of a hut in the woods with a hut and woods .
# P-551	-2.1391 -0.2867 -0.0465 -1.3118 -1.7048 -0.3480 -1.2188 -2.0716 -0.7519 -1.5975 -0.5982 -2.1033 -0.1137 -0.0007
# S-956	<unk> eines hundes auf einem baumstamm mitten im wald
# T-956	black and white photo of a dog on a log in the middle of a forest
# H-956	-0.7524448037147522	a <unk> dog on a log in the middle of a forest in the forest .
# D-956	-0.7524448037147522	a <unk> dog on a log in the middle of a forest in the forest .
# P-956	-1.1204 -3.1806 -0.4830 -1.2918 -0.1661 -1.0298 -0.9214 -0.0695 -0.2164 -0.0060 -0.6076 -0.0717 -1.9119 -0.2115 -0.7497 -0.7520 -0.0023
# S-940	eine <unk> eines einzelnen <unk> über einem gewässer .
# T-940	a black and white picture of the back of a single engine plane over water .
# H-940	-1.0598523616790771	a large group of a <unk> over a body of water .
# D-940	-1.0598523616790771	a large group of a <unk> over a body of water .
# P-940	-0.0577 -4.3056 -2.3972 -0.0177 -0.5444 -3.0615 -3.0800 -0.2285 -0.0166 -0.0005 -0.0025 -0.0660 -0.0000
# S-865	eine <unk> eines nebligen <unk> mit <unk> bäumen .
# T-865	a black and white photo of a misty day with <<unk>> trees in a field .
# H-865	-0.8828616738319397	a <unk> of a foggy area with a foggy trees .
# D-865	-0.8828616738319397	a <unk> of a foggy area with a foggy trees .
# P-865	-0.0509 -3.0170 -0.9742 -0.1229 -0.1801 -4.2143 -0.0863 -0.5949 -0.5403 -0.7637 -0.0498 -0.0000
# S-547	ein <unk> mit <unk> <unk> wirft einen ball .
# T-547	a baseball player is wearing a red and white <<unk>> uniform and throwing a ball .
# H-547	-0.7529836297035217	a <unk> pitcher is throwing a ball .
# D-547	-0.7529836297035217	a <unk> pitcher is throwing a ball .
# P-547	-0.1533 -1.9753 -2.4986 -1.4603 -0.0679 -0.0444 -0.1051 -0.4719 -0.0001
# S-313	jemand auf einem schwarz-gelben <unk> , im hintergrund boote
# T-313	a person on a black and yellow jet ski with boats in the background .
# H-313	-0.7496712803840637	someone on a <unk> and black <unk> in the background .
# D-313	-0.7496712803840637	someone on a <unk> and black <unk> in the background .
# P-313	-0.1270 -1.7088 -0.4579 -1.6278 -1.0944 -0.5272 -1.2304 -0.9289 -0.1079 -0.1065 -1.0788 -0.0005
# S-144	ein kiesweg mit <unk> neben stark <unk> gebäuden .
# T-144	a gravel alleyway with over grown grass along the sides of <<unk>> out buildings .
# H-144	-1.0465137958526611	a <unk> view of a <unk> road next to buildings .
# D-144	-1.0465137958526611	a <unk> view of a <unk> road next to buildings .
# P-144	-0.1114 -1.0321 -2.7240 -0.3254 -0.7623 -1.7053 -2.5542 -2.2197 -0.0176 -1.0149 -0.0901 -0.0012
# S-918	eine <unk> eines älteren asiatischen mannes in einer menschenmenge
# T-918	a black and white photo of an elderly asian man in a crowd .
# H-918	-0.8017258644104004	an asian man in an asian man in an asian crowd of people .
# D-918	-0.8017258644104004	an asian man in an asian man in an asian crowd of people .
# P-918	-0.8074 -0.3777 -0.0861 -1.2537 -0.0860 -0.0064 -0.8258 -2.7740 -0.5080 -0.0061 -2.5082 -0.1138 -0.4513 -2.2213 -0.0001
# S-838	ein kleines <unk> in der mitte eines <unk> gewässers
# T-838	a <<unk>> of trees in the middle of a <<unk>> body of water .
# H-838	-0.41448140144348145	a small <unk> in the middle of a body of water .
# D-838	-0.41448140144348145	a small <unk> in the middle of a body of water .
# P-838	-0.0569 -0.1845 -2.1988 -2.0923 -0.0275 -0.0098 -0.0004 -0.0812 -0.2587 -0.0235 -0.0222 -0.4323 -0.0000
# S-386	vater und sohn fahren auf der straße roller .
# T-386	a father and his son are rolling on the street with a roller coaster
# H-386	-0.30137601494789124	a father and son riding a scooter on the street .
# D-386	-0.30137601494789124	a father and son riding a scooter on the street .
# P-386	-0.3925 -0.1859 -0.0008 -0.0068 -0.3738 -1.5303 -0.0025 -0.2888 -0.0062 -0.8027 -0.0262 -0.0001
# S-310	ein <unk> alter <unk> voller menschen auf der straße
# T-310	a orange and white old model volkswagen van full with people on the road
# H-310	-0.6262372136116028	an old <unk> full of people on the street full of the street .
# D-310	-0.6262372136116028	an old <unk> full of people on the street full of the street .
# P-310	-0.6574 -0.0171 -3.0668 -0.4692 -0.0291 -0.0150 -2.5035 -0.0309 -0.0264 -0.1235 -0.0839 -1.5040 -0.5826 -0.2840 -0.0001
# S-1061	ein <unk> in einer <unk> mit grauem himmel .
# T-1061	a <<unk>> in the rolling hills have dark , gray skies overhead .
# H-1061	-0.6087048649787903	a <unk> man in a gray sky with a gray sky .
# D-1061	-0.6087048649787903	a <unk> man in a gray sky with a gray sky .
# P-1061	-0.2092 -2.9479 -2.8655 -0.2908 -0.1089 -0.0071 -0.9755 -0.0949 -0.2125 -0.1584 -0.0077 -0.0347 -0.0001
# S-767	viele <unk> sind wie zu einem kunstwerk gestapelt .
# T-767	many of the wooden bars were stacked in an artistic way .
# H-767	-1.0841121673583984	many <unk> are about to play art in a piece of art .
# D-767	-1.0841121673583984	many <unk> are about to play art in a piece of art .
# P-767	-0.0771 -1.7379 -1.2983 -2.8319 -0.0228 -3.5334 -1.1830 -1.3209 -0.9669 -1.1823 -0.0471 -0.8400 -0.1361 -0.0000
# S-631	dieses bild zeigt eine holzbank draußen im wald .
# T-631	this image is of a wooden bench sitting out in the woods .
# H-631	-0.4093913733959198	this is a picture is showing a wooden bench outside in the woods .
# D-631	-0.4093913733959198	this is a picture is showing a wooden bench outside in the woods .
# P-631	-0.0819 -0.3035 -0.3051 -0.0558 -0.4553 -1.8874 -0.0700 -1.0661 -0.3196 -0.6276 -0.4117 -0.0459 -0.5033 -0.0068 -0.0009
# S-593	leute sitzen in einem öffentlichen park im gras .
# T-593	a bunch of people sitting in a public park on the grass .
# H-593	-0.3853595554828644	people sit in a public park .
# D-593	-0.3853595554828644	people sit in a public park .
# P-593	-0.0014 -0.8526 -0.2469 -0.7100 -0.0340 -0.2964 -0.9414 -0.0002
# S-514	ein kleiner bach zwischen zwei großen felsen im schnee
# T-514	a small creek in the middle of two large rocks in the snow
# H-514	-0.2674737572669983	a small stream between two large rocks in the snow .
# D-514	-0.2674737572669983	a small stream between two large rocks in the snow .
# P-514	-0.0811 -0.2991 -0.6406 -0.7651 -0.0031 -0.2924 -0.5287 -0.1480 -0.0634 -0.0119 -0.3760 -0.0002
# S-409	ein kleiner baum <unk> aus einer <unk> heraus .
# T-409	a small tree is growing out of a <<unk>> in a rock .
# H-409	-0.5752490162849426	a small tree trunk out of a tree .
# D-409	-0.5752490162849426	a small tree trunk out of a tree .
# P-409	-0.0294 -0.4762 -0.0537 -2.3072 -2.3156 -0.1023 -0.1259 -0.0346 -0.3074 -0.0001
# S-289	zwei fußballspieler verschiedener mannschaften kämpfen um den ball .
# T-289	two soccer players in different uniforms struggle to take control of the ball
# H-289	-0.5566513538360596	two soccer players are fighting for the ball .
# D-289	-0.5566513538360596	two soccer players are fighting for the ball .
# P-289	-0.0068 -0.0431 -0.0175 -2.0631 -2.0906 -0.4936 -0.0884 -0.0364 -0.7270 -0.0001
# S-183	eine <unk> steckt in den <unk> eines <unk> .
# T-183	a black bird <<unk>> is stuck in the opening of wire fence .
# H-183	-1.0790531635284424	a mountain hiker is digging the foot of a mountain .
# D-183	-1.0790531635284424	a mountain hiker is digging the foot of a mountain .
# P-183	-0.1023 -0.8570 -3.3477 -0.3836 -2.0107 -2.1699 -0.7494 -0.3824 -0.1443 -1.3037 -1.4975 -0.0001
# S-179	zwei kinder in winterkleidung posieren für ein <unk> .
# T-179	two kids wearing winter outfit <<unk>> for a picture in black and white
# H-179	-0.5357552766799927	two children in winter clothes pose for a picture .
# D-179	-0.5357552766799927	two children in winter clothes pose for a picture .
# P-179	-0.0061 -0.6184 -0.5655 -0.0206 -0.6530 -0.8488 -0.0009 -0.2043 -2.4421 -0.5336 -0.0000
# S-167	ein mann steht im <unk> von leeren <unk> .
# T-167	a man stands in a <<unk>> aisle of rows of empty <<unk>> .
# H-167	-0.7024127244949341	a man stands in an empty auditorium .
# D-167	-0.7024127244949341	a man stands in an empty auditorium .
# P-167	-0.0666 -0.0167 -1.3374 -0.0736 -0.9797 -0.0016 -3.2573 -0.5884 -0.0004
# S-162	ein brauner hund beißt gleich einen schwarz-weißen hund .
# T-162	a brown dog is about to bite a black and white dog .
# H-162	-0.26987969875335693	a brown dog is about to get a black and white dog .
# D-162	-0.26987969875335693	a brown dog is about to get a black and white dog .
# P-162	-0.0573 -0.0035 -0.0122 -0.3736 -0.0141 -0.0026 -2.3337 -0.0408 -0.7018 -0.1529 -0.0128 -0.0033 -0.0698 -0.0001
# S-4	drei mädchen stehen vor dem fenster eines gebäudes .
# T-4	three girls are standing in front of a window of a building .
# H-4	-0.2516903877258301	three girls stand outside the window of a building .
# D-4	-0.2516903877258301	three girls stand outside the window of a building .
# P-4	-0.0230 -0.0087 -0.6434 -1.6593 -0.1617 -0.1754 -0.0124 -0.0453 -0.0012 -0.0380 -0.0002
# S-1019	ein <unk> auto steht vor einem <unk> anhänger .
# T-1019	a silver car sits in front of a bright pink trailer .
# H-1019	-0.36189794540405273	a <unk> car is standing in front of a trailer .
# D-1019	-0.36189794540405273	a <unk> car is standing in front of a trailer .
# P-1019	-0.1478 -1.8318 -0.5597 -1.2910 -0.0469 -0.2325 -0.0009 -0.0027 -0.0356 -0.1097 -0.0841 -0.0001
# S-768	kleiner schuppen mit <unk> tür im hof eines hauses
# T-768	small shed with the door open on the yard of a house
# H-768	-0.8657047748565674	small shed walking in the doorway of a house with a house in the yard .
# D-768	-0.8657047748565674	small shed walking in the doorway of a house with a house in the yard .
# P-768	-0.5879 -1.6426 -2.9698 -0.8898 -0.5529 -1.7667 -0.1162 -0.1816 -0.5133 -1.8541 -0.5119 -0.7603 -0.2907 -0.4199 -1.3584 -0.3009 -0.0000
# S-390	ein schwarzer hund mit einem stock im maul .
# T-390	a black dog with a stick in the trunk
# H-390	-0.13399890065193176	a black dog with a stick in its mouth .
# D-390	-0.13399890065193176	a black dog with a stick in its mouth .
# P-390	-0.0781 -0.0009 -0.0040 -0.0807 -0.0018 -0.0039 -0.0084 -0.8020 -0.0016 -0.4925 -0.0001
# S-455	mehrere leute laufen schnell aus dem kalten wasser .
# T-455	several people are running out of the cold water .
# H-455	-0.4963318705558777	several people are running quickly from the water .
# D-455	-0.4963318705558777	several people are running quickly from the water .
# P-455	-0.1749 -0.0498 -0.5506 -0.1794 -1.4897 -1.3478 -0.3689 -0.6309 -0.1714 -0.0000
# S-373	ein süßer kleiner vogel auf dem ast eines baumes
# T-373	a cute little bird on the branch of a tree
# H-373	-0.5160455107688904	a cute little bird on the tree branch of a tree branch .
# D-373	-0.5160455107688904	a cute little bird on the tree branch of a tree branch .
# P-373	-0.0973 -1.8012 -0.9303 -0.7343 -1.1231 -0.4949 -0.1945 -0.1943 -0.0043 -0.0166 -0.0468 -0.1610 -1.4261 -0.0001
# S-334	ein wanderweg , auf dem keine pferde <unk> sind
# T-334	hiking trail in the country with no horses <<unk>> .
# H-334	-1.3949060440063477	a hiking , biker , riding horses , along a hiking trail .
# D-334	-1.3949060440063477	a hiking , biker , riding horses , along a hiking trail .
# P-334	-0.1536 -1.8399 -2.2733 -2.2843 -0.2976 -2.4565 -0.7995 -0.2835 -3.9751 -0.6691 -2.6135 -1.4083 -0.4742 -0.0003
# S-328	boote auf dem wasser , im hintergrund eine stadt
# T-328	boats on the water with a city in the background
# H-328	-0.6186000108718872	boats in water on a city with water in the background .
# D-328	-0.6186000108718872	boats in water on a city with water in the background .
# P-328	-0.2693 -0.5502 -0.8899 -1.5410 -1.6831 -0.0173 -1.3743 -0.3999 -0.3360 -0.2209 -0.0152 -0.7446 -0.0001
# S-305	mädchen mit schwarzen <unk> tanzen auf einer bühne .
# T-305	girls wearing black leotards are dancing on a stage .
# H-305	-0.5422619581222534	girls with black <unk> dance on a stage .
# D-305	-0.5422619581222534	girls with black <unk> dance on a stage .
# P-305	-0.8153 -0.5425 -0.0058 -2.3875 -1.3294 -0.1966 -0.1259 -0.0069 -0.0125 -0.0001
# S-276	mädchen , das am meer aus der brandung hochspringt
# T-276	girl jumping out of the surf of the ocean .
# H-276	-0.9266440868377686	the girl is jumping out of the ocean on the ocean .
# D-276	-0.9266440868377686	the girl is jumping out of the ocean on the ocean .
# P-276	-2.4159 -0.1036 -0.7926 -1.1510 -1.7710 -1.8869 -0.0669 -0.2185 -2.4719 -0.0787 -0.7587 -0.3306 -0.0001
# S-245	ein mann wartet und betrachtet einen vorbeifahrenden zug .
# T-245	a man is waiting and watching a train go by
# H-245	-0.5758531093597412	a man waiting for a train while waiting on a train .
# D-245	-0.5758531093597412	a man waiting for a train while waiting on a train .
# P-245	-0.1089 -0.0104 -1.4479 -1.0953 -0.1901 -0.0005 -1.4664 -0.1223 -2.3407 -0.6330 -0.0010 -0.0696 -0.0000
# S-215	ein kind mit gelben ohrenschützern beobachtet eine <unk> .
# T-215	a child with yellow ear <<unk>> watches a show .
# H-215	-0.7686448693275452	a child with yellow earmuffs on is watching a ride .
# D-215	-0.7686448693275452	a child with yellow earmuffs on is watching a ride .
# P-215	-0.1858 -0.0928 -0.6142 -0.1062 -1.6796 -1.8599 -0.4348 -0.2597 -0.0717 -3.8772 -0.0419 -0.0000
# S-100	eine frau mit hund geht am <unk> entlang .
# T-100	a woman and her dog passing by the lake shore
# H-100	-0.5259689688682556	a woman with a dog walking along the edge of a <unk> .
# D-100	-0.5259689688682556	a woman with a dog walking along the edge of a <unk> .
# P-100	-0.1050 -0.0124 -0.3631 -0.3959 -0.5360 -0.6703 -0.3379 -0.7506 -1.3406 -0.0179 -0.2076 -1.9456 -0.6806 -0.0001
# S-22	ein brauner hund mit einer <unk> auf dem <unk>
# T-22	a brown dog with a watering can on the <<unk>>
# H-22	-0.9042289853096008	a brown dog with a tan dog on the stoop .
# D-22	-0.9042289853096008	a brown dog with a tan dog on the stoop .
# ...
# T-69	a man with a beard is seen through a window holding a cup , while a man in the background reads a newspaper .
# H-69	-0.4522877037525177	a man is looking through a newspaper with a man reading a newspaper in the background .
# D-69	-0.4522877037525177	a man is looking through a newspaper with a man reading a newspaper in the background .
# P-69	-0.1148 -0.6478 -0.9502 -0.1534 -0.5027 -0.0169 -0.7462 -0.3618 -0.1015 -1.1750 -2.0309 -0.0614 -0.1789 -1.0209 -0.0235 -0.0017 -0.0524 -0.0012
# S-160	eine junge frau mit <unk> , die eine jacke trägt , steht in einer u-bahn mit gekreuzten armen an die wand gelehnt .
# T-160	a young <<unk>> woman with a jacket on stands in a subway train against the wall with her arms crossed .
# H-160	-0.6285913586616516	a young woman with a <unk> jacket stands against the wall with a wall .
# D-160	-0.6285913586616516	a young woman with a <unk> jacket stands against the wall with a wall .
# P-160	-0.0838 -0.0467 -0.0762 -0.9664 -0.4119 -2.0222 -0.1892 -0.8035 -0.6305 -1.5394 -0.0060 -0.7924 -0.6819 -0.2055 -1.6004 -0.0014
# S-324	eine frau , die wie in <unk> gekleidet ist , sitzt in einem raum mit gelber <unk> mit einem buch am tisch .
# T-324	a woman dressed in pioneer clothing sitting at a table with a book in a room with yellow <<unk>> .
# H-324	-0.4665953814983368	a woman dressed in yellow is sitting at a table with a book in a <unk> room .
# D-324	-0.4665953814983368	a woman dressed in yellow is sitting at a table with a book in a <unk> room .
# P-324	-0.2041 -0.0085 -0.2912 -0.3607 -1.1608 -1.4988 -0.1041 -0.3520 -0.3597 -0.0219 -0.4148 -0.2314 -0.2291 -0.8905 -0.0285 -2.6095 -0.0224 -0.0771 -0.0001
# S-800	eine frau betreibt ihren <unk> , wo es mit schokolade <unk> <unk> gibt , und mehrere personen sehen sich ihre ware an .
# T-800	a woman running her candy stand which carries chocolate covered <<unk>> while people look at her wares .
# H-800	-1.2346376180648804	a woman is doing different market where there is <unk> and a bunch of people are watching their sell .
# D-800	-1.2346376180648804	a woman is doing different market where there is <unk> and a bunch of people are watching their sell .
# P-800	-0.1172 -0.0086 -0.4149 -0.9756 -2.0716 -4.6401 -1.2445 -0.8863 -0.5318 -1.6445 -0.4336 -3.3147 -2.6907 -0.0071 -0.0739 -0.3008 -1.6905 -0.6589 -3.7909 -0.4310 -0.0001
# S-906	die decke eines gebäudes , das wie ein bahnhof aussieht , wird von dem licht angeleuchtet , das durch große fenster <unk> .
# T-906	the ceiling of what looks like a train station is bathed in light from large windows .
# H-906	-0.9018526673316956	the ceiling of a building where the light is being <unk> .
# D-906	-0.9018526673316956	the ceiling of a building where the light is being <unk> .
# P-906	-0.0928 -1.3514 -0.0075 -0.0855 -0.0472 -2.0872 -0.4979 -1.1871 -0.8940 -1.1140 -1.5445 -2.8139 -0.0011
# S-249	ein mann mit einem schutzhelm , blauen t-shirt und rucksack fährt mit dem fahrrad durch eine <unk> waldgegend mit weißen <unk> .
# T-249	a man wearing a safety helmet , blue t-shirt , and back pack , is bicycling through an <<unk>> of vegetation in a wooded area consisting of white <<unk>> trees .
# H-249	-0.5518602728843689	a man wearing a hard hat and a blue shirt riding a bicycle through a wooded area with a white backpack .
# D-249	-0.5518602728843689	a man wearing a hard hat and a blue shirt riding a bicycle through a wooded area with a white backpack .
# P-249	-0.2551 -0.0184 -1.5748 -0.0033 -0.1685 -0.0160 -1.2251 -0.5468 -0.0118 -0.8014 -1.2160 -0.6595 -0.3650 -0.3886 -0.0555 -2.1227 -0.0062 -0.4959 -0.2545 -0.0618 -1.0633 -1.3769 -0.0058
# S-666	die sonne scheint durch einen <unk> , im hintergrund ist eine lichtung mit einem kleinen see und einem picknicktisch zu sehen .
# T-666	the sun casting through a forest of pine trees and a clearing in the background with a small lake and <<unk>> table .
# H-666	-0.4236147701740265	the sun appears to be a picnic table with a small tree in the background .
# D-666	-0.4236147701740265	the sun appears to be a picnic table with a small tree in the background .
# P-666	-0.0282 -0.0056 -0.5922 -0.0012 -0.0537 -0.3399 -1.7002 -0.1385 -1.8975 -0.0153 -0.0649 -2.0509 -0.1462 -0.0521 -0.0056 -0.1088 -0.0007
# S-700	ein kleines mädchen , überwiegend rosa gekleidet , sitzt an einem leicht bewölkten tag <unk> auf einer skulptur in einem park .
# T-700	a young girl dressed mostly in pink is <<unk>> sitting on a sculpture at a park on a partly cloudy day .
# H-700	-0.6579399108886719	a little girl dressed in pink is sitting at a sculpture on a sculpture in a park .
# D-700	-0.6579399108886719	a little girl dressed in pink is sitting at a sculpture on a sculpture in a park .
# P-700	-0.1054 -0.4630 -0.0333 -0.6842 -0.7629 -0.2087 -1.0465 -0.0820 -3.1732 -0.0257 -1.1430 -0.2262 -0.0290 -2.9225 -0.6909 -0.0598 -0.5629 -0.2802 -0.0013
# S-134	ein <unk> einer frau , die auf einer bank neben einem gewässer sitzt und eine an ihrem hund <unk> leine hält .
# T-134	a black and white scene of a woman sitting on a bench holding a leash on her dog beside water .
# H-134	-0.5581585764884949	a <unk> woman is sitting on a bench next to a leash and holding a dog on a body of water .
# D-134	-0.5581585764884949	a <unk> woman is sitting on a bench next to a leash and holding a dog on a body of water .
# P-134	-0.0803 -1.6335 -0.1620 -1.9733 -1.4053 -0.0291 -0.0086 -0.0221 -1.6576 -0.0002 -0.1619 -0.7868 -0.4277 -0.3665 -0.0503 -0.0579 -1.6213 -0.6562 -1.5325 -0.0006 -0.0087 -0.1911 -0.0039
# S-109	eine <unk> von leuten , die auf einem gepflasterten gehweg gehen , wobei ein mann neben <unk> in leuchtenden farben steht .
# T-109	a scene from the air of people walking on cobblestone sidewalk with a man standing near brightly colored prayer mats .
# H-109	-0.9533590078353882	a <unk> of people standing on a brick sidewalk , a man with bright colored clothing and a man standing on the sidewalk .
# D-109	-0.9533590078353882	a <unk> of people standing on a brick sidewalk , a man with bright colored clothing and a man standing on the sidewalk .
# P-109	-0.1211 -1.9797 -0.0603 -0.0070 -1.9760 -0.0871 -0.0483 -1.6396 -1.1497 -1.0872 -1.3936 -0.0474 -1.9760 -1.4533 -0.4343 -1.6997 -0.6198 -0.4741 -2.4252 -1.3459 -1.2640 -0.6016 -0.7785 -1.1644 -0.0004
# S-460	zwei hunde , ein brauner und ein schwarzer , spielen miteinander , und der braune hund sitzt auf dem schwarzen hund .
# T-460	two dogs , a brown and black , are playing and brown dog is sitting on the black dog .
# H-460	-0.3992127478122711	two dogs , one brown and a black dog sitting on the brown dog .
# D-460	-0.3992127478122711	two dogs , one brown and a black dog sitting on the brown dog .
# P-460	-0.0149 -0.0173 -0.1299 -0.5527 -0.4632 -0.0479 -0.8327 -0.0062 -0.0077 -1.6291 -0.9802 -0.0444 -0.0115 -0.6092 -1.0404 -0.0001
# S-1033	dieses bild zeigt ein männliches und ein <unk> <unk> , die an einem tisch sitzen und eine mahlzeit &quot; <unk> . &quot;
# T-1033	this image is of a man and woman skeleton sitting at a table &quot; eating &quot; a meal .
# H-1033	-0.9349521994590759	this image is a picture and a male boy are sitting at a table and reading a meal .
# D-1033	-0.9349521994590759	this image is a picture and a male boy are sitting at a table and reading a meal .
# P-1033	-0.0880 -1.6473 -0.3272 -0.8328 -1.0495 -0.2922 -0.7766 -1.8260 -2.6042 -1.7155 -0.1149 -1.0242 -0.0484 -0.0341 -1.3541 -1.9701 -0.5429 -1.0842 -0.5343 -0.8325
# S-520	ein junge , der in einem offenen bereich in der stadt auf dem beton skateboard fährt , im hintergrund ein theater .
# T-520	a boy skateboarding on concrete in an open area in the city with a <<unk>> in the background .
# H-520	-0.4519962966442108	a boy skateboarding in an open area with a theater in the background .
# D-520	-0.4519962966442108	a boy skateboarding in an open area with a theater in the background .
# P-520	-0.2452 -0.0710 -0.8714 -0.0629 -1.6606 -0.3619 -0.2831 -0.8458 -0.4671 -1.5818 -0.1235 -0.0552 -0.0576 -0.0923 -0.0007
# S-323	ein footballspieler mit rotem trikot wirft den ball , während ein anderer spieler mit einem weißen trikot auf ihn zu rennt .
# T-323	a football player in red throws the ball while another player in white runs toward him .
# H-323	-0.5790970325469971	a football player in a red jersey is throwing the ball while another player runs towards him .
# D-323	-0.5790970325469971	a football player in a red jersey is throwing the ball while another player runs towards him .
# P-323	-0.5076 -0.0422 -0.0665 -0.8937 -0.8819 -0.0012 -0.4026 -1.4009 -0.3866 -0.4155 -0.0391 -1.5717 -0.0331 -0.1560 -2.0431 -1.5535 -0.0312 -0.5762 -0.0004
# S-950	ein <unk> baseman der <unk> <unk> bereitet sich darauf vor , den ball zu fangen , während der pitcher sich dreht .
# T-950	a <<unk>> <<unk>> second baseman prepares to field the ball as the pitcher winds up .
# H-950	-0.8264210820198059	a <unk> baseman is getting ready to catch the ball while the pitcher is getting ready to catch it .
# D-950	-0.8264210820198059	a <unk> baseman is getting ready to catch the ball while the pitcher is getting ready to catch it .
# P-950	-0.2419 -1.6087 -3.5271 -1.6566 -0.3891 -0.1163 -0.0041 -0.2333 -0.9962 -0.0289 -0.8689 -1.0760 -1.5032 -2.8493 -1.0818 -0.0055 -0.0248 -0.2490 -0.7678 -0.1262 -0.0001
# S-478	ein junger mann macht eine pause , um sein handy zu <unk> , was auch eine frau im hintergrund macht .
# T-478	a young man pauses to check his cell phone , as does a woman in the background .
# H-478	-0.5313190221786499	a young man taking a break to take a cellphone in the background .
# D-478	-0.5313190221786499	a young man taking a break to take a cellphone in the background .
# P-478	-0.0866 -0.0106 -0.0106 -1.1613 -0.0264 -0.0861 -1.8547 -1.2025 -0.0152 -1.9389 -1.2946 -0.0850 -0.0079 -0.1888 -0.0005
# S-229	eine frau mit lockigen haaren und einer blauen jacke geht auf einem bürgersteig in der stadt an einem schaufenster vorbei .
# T-229	a woman with curly hair and blue jacket walking by a shop window on a city sidewalk .
# H-229	-0.49342256784439087	a woman with curly hair and a blue jacket walks past a window in a city window .
# D-229	-0.49342256784439087	a woman with curly hair and a blue jacket walks past a window in a city window .
# P-229	-0.2020 -0.0271 -0.1727 -0.0634 -0.5450 -0.1171 -0.0828 -0.0103 -0.0021 -1.1484 -0.4039 -0.0668 -1.7072 -1.2943 -0.6495 -0.5487 -1.1102 -1.2233 -0.0004
# S-119	ein mann und eine frau sitzen auf einer parkbank und betrachten einen anderen mann und eine frau , die vorbeigehen .
# T-119	a man and a woman are sitting on a park bench watching another man and woman walk by .
# H-119	-0.3862716853618622	a man and woman are sitting on a park bench looking at another man and looking at a park .
# D-119	-0.3862716853618622	a man and woman are sitting on a park bench looking at another man and looking at a park .
# P-119	-0.1180 -0.0096 -0.0008 -0.9453 -1.5652 -0.0249 -0.1530 -0.0414 -0.0079 -0.0273 -1.1988 -0.1384 -0.2337 -0.0582 -0.2303 -1.4899 -0.5432 -1.0414 -0.2095 -0.0748 -0.0002
# S-404	bild eines <unk> flusses , im hintergrund häuser und ein zug , der auf dem berg über eine brücke fährt .
# T-404	picture of white water river , house in background , and train crossing bridge on the hill behind .
# H-404	-0.8149605393409729	here is a picture of a river and a bridge over the background .
# D-404	-0.8149605393409729	here is a picture of a river and a bridge over the background .
# P-404	-1.2195 -0.2512 -0.0527 -2.4455 -0.0160 -0.1598 -0.6553 -0.8331 -1.3924 -3.3078 -1.0539 -0.3689 -0.0406 -0.4273 -0.0004
# S-682	große weiße betonstufen mit überall <unk> bäumen und einem mann , der traurig mit in die hände <unk> kopf <unk> .
# T-682	large white concrete stairs with trees throughout and a man sad sitting with his head in his hands .
# H-682	-1.1572320461273193	large white and black <unk> with a man all over his head and <unk> with a <unk> .
# D-682	-1.1572320461273193	large white and black <unk> with a man all over his head and <unk> with a <unk> .
# P-682	-0.3785 -0.0036 -0.6530 -2.2791 -1.4433 -1.3878 -1.7896 -0.1038 -2.1801 -0.8608 -1.0372 -0.7348 -1.6275 -2.3187 -1.2892 -1.5617 -0.4560 -1.8818 -0.0011
# S-372	zwei <unk> auf einem platz , die zur <unk> violette trikots und zur <unk> weiße trikots tragen und einander <unk> .
# T-372	two football teams on a field with half wearing purple uniforms and half wearing white uniforms tackling each other .
# H-372	-0.9984780550003052	two <unk> dogs on a purple and white jerseys not to each other and the white jerseys .
# D-372	-0.9984780550003052	two <unk> dogs on a purple and white jerseys not to each other and the white jerseys .
# P-372	-0.0084 -3.3402 -1.8818 -0.8613 -0.0769 -0.9818 -0.7693 -0.2545 -0.3026 -2.9682 -2.6423 -0.9291 -0.0033 -1.0944 -1.1547 -0.0737 -0.1309 -1.4958 -0.0020
# S-697	zwei junge männer in bunten badehosen halten sich an einem <unk> fest , da sie von einem boot gezogen werden .
# T-697	two young men in colorful swim trunks hold onto a rubber raft for as they are towed by a boat .
# H-697	-0.6297694444656372	two young men in colorful bathing suits are being pulled by a boat .
# D-697	-0.6297694444656372	two young men in colorful bathing suits are being pulled by a boat .
# P-697	-0.0072 -0.0124 -0.0274 -0.1670 -2.1561 -0.7801 -0.7042 -0.6316 -1.1165 -0.1392 -0.8043 -0.3916 -0.2459 -2.2626 -0.0005
# S-42	dieses bild zeigt ein kleines mädchen , das sich an das bett seiner eltern lehnt und sich im spiegel betrachtet .
# T-42	this image is of a little girl leaning against her parents bed while she &apos;s looking at herself in the mirror .
# H-42	-0.5228613615036011	this picture is of a little girl looking at the mirror and leaning on his bed .
# D-42	-0.5228613615036011	this picture is of a little girl looking at the mirror and leaning on his bed .
# P-42	-0.1651 -1.5331 -0.1836 -0.3853 -0.1043 -0.5000 -0.0057 -1.5086 -0.0151 -0.6527 -0.6021 -0.0489 -0.7561 -0.1955 -0.4352 -1.7535 -0.5655 -0.0013
# S-968	eine weiße und eine silberfarbene limousine parken unter einer bemalten wand , auf der zwei braune käfer hellrosa blumen halten .
# T-968	a white sedan and a silver sedan is parked under a graffitied wall containing two brown <<unk>> holding light pink flowers .
# H-968	-1.1568806171417236	a white and brown dog are parking lot with two green flowers on the wall .
# D-968	-1.1568806171417236	a white and brown dog are parking lot with two green flowers on the wall .
# P-968	-0.0816 -0.0059 -0.0230 -3.8662 -2.5468 -0.7660 -1.8073 -0.0152 -2.6702 -0.8871 -2.6822 -0.5282 -1.1877 -1.2096 -0.6551 -0.7343 -0.0007
# S-836	drei personen auf <unk> fahren durch einen schlammigen <unk> der strecke und <unk> schlamm in richtung des oder der <unk> .
# T-836	three people on dirt bikes are riding through a muddy part of the course and <<unk>> mud to fly at the camera person .
# H-836	-0.7933001518249512	three people on horseback riding through a muddy trail in the mud and the mud .
# D-836	-0.7933001518249512	three people on horseback riding through a muddy trail in the mud and the mud .
# P-836	-0.0405 -0.0242 -0.8361 -3.2324 -1.0936 -0.6106 -0.0755 -0.0478 -1.7244 -1.7060 -0.0891 -0.2269 -0.3723 -1.7019 -0.5471 -1.1573 -0.0003
# S-751	dieses bild ist im freien aufgenommen , mit bergen im hintergrund und ein paar bäumen und einer bank im vordergrund .
# T-751	this is a picture of a outdoor scene with mountains in the background and a couple of trees and a bench in the foreground .
# H-751	-0.7925001978874207	this is a picture is outside , with a couple and mountains and a couple are in the background .
# D-751	-0.7925001978874207	this is a picture is outside , with a couple and mountains and a couple are in the background .
# P-751	-0.0784 -0.6386 -1.2189 -0.2425 -1.1944 -0.4713 -0.4715 -2.2106 -0.0858 -0.5250 -1.9549 -1.4155 -0.7566 -0.3635 -0.5359 -1.9360 -1.7698 -0.0434 -0.3243 -0.4011 -0.0044
# INFO:fairseq_cli.generate:NOTE: hypothesis and token scores are output in base 2
# INFO:fairseq_cli.generate:Translated 1,064 sentences (14,882 tokens) in 29.8s (35.76 sentences/s, 500.10 tokens/s)
# Generate test with beam=5: BLEU4 = 25.99, 62.6/35.2/20.4/12.2 (BP=0.955, ratio=0.956, syslen=13818, reflen=14455)

# %% [markdown]
# **Increasing just the Beam Size to see difference in Bleu Score**

# %%
# ckpt_best, beam=10
! fairseq-generate data-bin/multi30k.tokenized.de-en \
    --path checkpoints/checkpoint_best.pt \
    --batch-size 128 \
    --beam 10 \
    --seed 1 \
    --scoring bleu \
    --quiet \
    --wandb-project "Multi 30K En to De Translation"
# Out:
# 2023-11-24 15:09:16.328735: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 15:09:16.328813: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 15:09:16.328861: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-24 15:09:16.344242: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 15:09:18.366721: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:hydra.core.utils:Setting JobRuntime:name=UNKNOWN_NAME
# DEBUG:hydra.core.utils:Setting JobRuntime:name=utils
# INFO:fairseq_cli.generate:{'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': 'Multi 30K En to De Translation', 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': False, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': 'checkpoints/checkpoint_best.pt', 'post_process': None, 'quiet': True, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': False, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': None, 'batch_size': 128, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': None, 'batch_size_valid': 128, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 0, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.25], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False, 'debug_param_names': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_c ...
# INFO:fairseq.tasks.translation:[de] dictionary: 7864 types
# INFO:fairseq.tasks.translation:[en] dictionary: 5928 types
# INFO:fairseq_cli.generate:loading model(s) from checkpoints/checkpoint_best.pt
# INFO:fairseq.data.data_utils:loaded 1,071 examples from: data-bin/multi30k.tokenized.de-en/test.de-en.de
# INFO:fairseq.data.data_utils:loaded 1,071 examples from: data-bin/multi30k.tokenized.de-en/test.de-en.en
# INFO:fairseq.tasks.translation:data-bin/multi30k.tokenized.de-en test de-en 1071 examples
# INFO:fairseq.tasks.fairseq_task:can_reuse_epoch_itr = True
# INFO:fairseq.tasks.fairseq_task:reuse_dataloader = True
# INFO:fairseq.tasks.fairseq_task:rebuild_batches = False
# INFO:fairseq.tasks.fairseq_task:creating new batches for epoch 1
# INFO:fairseq_cli.generate:NOTE: hypothesis and token scores are output in base 2
# INFO:fairseq_cli.generate:Translated 1,064 sentences (14,874 tokens) in 54.7s (19.43 sentences/s, 271.68 tokens/s)
# Generate test with beam=10: BLEU4 = 26.17, 62.9/35.5/20.6/12.2 (BP=0.954, ratio=0.955, syslen=13810, reflen=14455)

# %% [markdown]
# **Generate Average Checkpoint (Ensemble)**

# %%
! python fairseq/scripts/average_checkpoints.py --inputs checkpoints --num-epoch-checkpoints 5 --output checkpoints/averaged.pt
# Out:
# 2023-11-24 15:05:50.062841: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 15:05:50.062913: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 15:05:50.062950: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-24 15:05:50.071909: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 15:05:51.540341: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:fairseq.tasks.text_to_speech:Please install tensorboardX: pip install tensorboardX
# Namespace(inputs=['checkpoints'], output='checkpoints/averaged.pt', num_epoch_checkpoints=5, num_update_checkpoints=None, num_best_checkpoints=0, checkpoint_upper_bound=None)
# averaging checkpoints:  ['checkpoints/checkpoint10.pt', 'checkpoints/checkpoint9.pt', 'checkpoints/checkpoint8.pt', 'checkpoints/checkpoint7.pt', 'checkpoints/checkpoint6.pt']
# Finished writing averaged checkpoint to checkpoints/averaged.pt

# %% [markdown]
# **Test dataset Performance over the Average checkpoint with Beam = 5**

# %%
# ckpt_avg, beam=5
! fairseq-generate data-bin/multi30k.tokenized.de-en \
    --path checkpoints/averaged.pt \
    --batch-size 128 \
    --beam 5 \
    --seed 1 \
    --scoring bleu \
    --quiet \
    --wandb-project "Multi 30K En to De Translation"
# Out:
# 2023-11-24 15:06:21.074604: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 15:06:21.074671: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 15:06:21.074719: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-24 15:06:21.083870: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 15:06:22.407837: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:fairseq.tasks.text_to_speech:Please install tensorboardX: pip install tensorboardX
# DEBUG:hydra.core.utils:Setting JobRuntime:name=UNKNOWN_NAME
# DEBUG:hydra.core.utils:Setting JobRuntime:name=utils
# INFO:fairseq_cli.generate:{'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': 'Multi 30K En to De Translation', 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': False, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': 'checkpoints/averaged.pt', 'post_process': None, 'quiet': True, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': False, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': None, 'batch_size': 128, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': None, 'batch_size_valid': 128, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 0, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.25], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False, 'debug_param_names': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_checkpoi ...
# INFO:fairseq.tasks.translation:[de] dictionary: 7864 types
# INFO:fairseq.tasks.translation:[en] dictionary: 5928 types
# INFO:fairseq_cli.generate:loading model(s) from checkpoints/averaged.pt
# INFO:fairseq.data.data_utils:loaded 1,071 examples from: data-bin/multi30k.tokenized.de-en/test.de-en.de
# INFO:fairseq.data.data_utils:loaded 1,071 examples from: data-bin/multi30k.tokenized.de-en/test.de-en.en
# INFO:fairseq.tasks.translation:data-bin/multi30k.tokenized.de-en test de-en 1071 examples
# INFO:fairseq.tasks.fairseq_task:can_reuse_epoch_itr = True
# INFO:fairseq.tasks.fairseq_task:reuse_dataloader = True
# INFO:fairseq.tasks.fairseq_task:rebuild_batches = False
# INFO:fairseq.tasks.fairseq_task:creating new batches for epoch 1
# INFO:fairseq_cli.generate:NOTE: hypothesis and token scores are output in base 2
# INFO:fairseq_cli.generate:Translated 1,064 sentences (14,469 tokens) in 27.1s (39.26 sentences/s, 533.87 tokens/s)
# Generate test with beam=5: BLEU4 = 26.74, 64.8/37.2/21.9/13.3 (BP=0.925, ratio=0.927, syslen=13405, reflen=14455)

# %% [markdown]
# **Test dataset Performance over the Average checkpoint with Beam increased**

# %%
# ckpt_avg, beam=10
! fairseq-generate data-bin/multi30k.tokenized.de-en \
    --path checkpoints/averaged.pt \
    --batch-size 128 \
    --beam 10 \
    --seed 1 \
    --scoring bleu \
    --quiet \
    --wandb-project "Multi 30K En to De Translation"
# Out:
# 2023-11-24 15:29:24.613533: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 15:29:24.613612: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 15:29:24.613657: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-24 15:29:24.624850: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 15:29:26.028232: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:hydra.core.utils:Setting JobRuntime:name=UNKNOWN_NAME
# DEBUG:hydra.core.utils:Setting JobRuntime:name=utils
# INFO:fairseq_cli.generate:{'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': 'Multi 30K En to De Translation', 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': False, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': 'checkpoints/averaged.pt', 'post_process': None, 'quiet': True, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': False, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': None, 'batch_size': 128, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': None, 'batch_size_valid': 128, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 0, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.25], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False, 'debug_param_names': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_checkpoi ...
# INFO:fairseq.tasks.translation:[de] dictionary: 7864 types
# INFO:fairseq.tasks.translation:[en] dictionary: 5928 types
# INFO:fairseq_cli.generate:loading model(s) from checkpoints/averaged.pt
# INFO:fairseq.data.data_utils:loaded 1,071 examples from: data-bin/multi30k.tokenized.de-en/test.de-en.de
# INFO:fairseq.data.data_utils:loaded 1,071 examples from: data-bin/multi30k.tokenized.de-en/test.de-en.en
# INFO:fairseq.tasks.translation:data-bin/multi30k.tokenized.de-en test de-en 1071 examples
# INFO:fairseq.tasks.fairseq_task:can_reuse_epoch_itr = True
# INFO:fairseq.tasks.fairseq_task:reuse_dataloader = True
# INFO:fairseq.tasks.fairseq_task:rebuild_batches = False
# INFO:fairseq.tasks.fairseq_task:creating new batches for epoch 1
# INFO:fairseq_cli.generate:NOTE: hypothesis and token scores are output in base 2
# INFO:fairseq_cli.generate:Translated 1,064 sentences (14,477 tokens) in 51.1s (20.80 sentences/s, 283.06 tokens/s)
# Generate test with beam=10: BLEU4 = 26.69, 64.9/37.2/21.8/13.2 (BP=0.925, ratio=0.928, syslen=13413, reflen=14455)

# %% [markdown]
# # Export the model

# %% [markdown]
# **Exporting the Averaged Checkpoint trained Model**

# %%
! mkdir -p trained_model
! cp data-bin/multi30k.tokenized.de-en/dict.de.txt trained_model/dict.de.txt
! cp data-bin/multi30k.tokenized.de-en/dict.en.txt trained_model/dict.en.txt
! cp checkpoints/averaged.pt trained_model/model.pt

# %% [markdown]
# **Using fairseq-interactive (with beam of 5 as it has highest BLEU SCORE) as it can take sentences as input as they go and translate**

# %%
! fairseq-interactive \
  --path trained_model/model.pt \
  --source-lang de --target-lang en \
  --tokenizer moses \
  --task translation --cpu \
  --beam 5 \
  trained_model/
# Out:
# 2023-11-24 15:36:53.654352: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 15:36:53.654432: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 15:36:53.654477: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-24 15:36:53.665368: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-24 15:36:55.087094: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:hydra.core.utils:Setting JobRuntime:name=UNKNOWN_NAME
# DEBUG:hydra.core.utils:Setting JobRuntime:name=utils
# INFO:fairseq_cli.interactive:{'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': True, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': False, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': None, 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': 'trained_model/model.pt', 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': None}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': False, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': False, 'max_tokens': None, 'batch_size': 1, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': None, 'batch_size_valid': None, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 0, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.25], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False, 'debug_param_names': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_checkpoints': -1, 'no_save': False, 'no_epoch_checkpoints': False, 'no_last_checkpoints': False, 'no_save_optimizer_state': False, 'best_checkpoint_metric': 'loss', 'maximize_best_checkpoint_metric': False, 'patience': -1, 'checkpoint_suffix': '', 'checkpoint_shard_count': 1, 'load_checkpoint_on_all_dp_ranks': False, ...
# INFO:fairseq.tasks.translation:[de] dictionary: 7864 types
# INFO:fairseq.tasks.translation:[en] dictionary: 5928 types
# INFO:fairseq_cli.interactive:loading model(s) from trained_model/model.pt
# INFO:fairseq_cli.interactive:NOTE: hypothesis and token scores are output in base 2
# INFO:fairseq_cli.interactive:Type the input sentence and press return:
# eine frau mit lockigen haaren und einer blauen jacke geht auf einem bürgersteig in der stadt an einem schaufenster vorbei .
# INFO:fairseq.tasks.fairseq_task:can_reuse_epoch_itr = True
# INFO:fairseq.tasks.fairseq_task:reuse_dataloader = True
# INFO:fairseq.tasks.fairseq_task:rebuild_batches = False
# INFO:fairseq.tasks.fairseq_task:creating new batches for epoch 1
# S-0	eine frau mit lockigen haaren und einer blauen jacke geht auf einem bürgersteig in der stadt an einem schaufenster vorbei .
# W-0	0.176	seconds
# H-0	-0.40713638067245483	a woman with curly curly hair and a blue jacket walks past a window on a city sidewalk .
# D-0	-0.40713638067245483	a woman with curly curly hair and a blue jacket walks past a window on a city sidewalk.
# P-0	-0.0750 -0.0205 -0.0964 -0.0246 -0.5516 -0.4122 -0.1106 -0.0484 -0.0083 -0.0019 -1.2137 -0.3577 -0.0364 -1.4694 -0.9580 -1.1975 -0.1993 -0.0275 -1.3336 -0.0002
# Traceback (most recent call last):
#   File "/usr/local/bin/fairseq-interactive", line 8, in <module>
#     sys.exit(cli_main())
#   File "/content/fairseq/fairseq_cli/interactive.py", line 313, in cli_main
#     distributed_utils.call_main(convert_namespace_to_omegaconf(args), main)
#   File "/content/fairseq/fairseq/distributed/utils.py", line 404, in call_main
#     main(cfg, **kwargs)
#   File "/content/fairseq/fairseq_cli/interactive.py", line 207, in main
#     for inputs in buffered_read(cfg.interactive.input, cfg.interactive.buffer_size):
#   File "/content/fairseq/fairseq_cli/interactive.py", line 45, in buffered_read
#     for src_str in h:
#   File "/usr/lib/python3.10/fileinput.py", line 256, in __next__
# KeyboardInterrupt
# ^C
